# %% [markdown]
# <a href="https://colab.research.google.com/github/ajeetranaut/Assignment/blob/master/TapReviewAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Tap Reviews.csv')

# %%
df.head()
# Out:
#         asins                                               name  \
# 0  B01BH83OOM  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 1  B01BH83OOM  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 2  B01BH83OOM  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 3  B01BH83OOM  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
# 4  B01BH83OOM  Amazon Tap - Alexa-Enabled Portable Bluetooth ...
#
#    reviews.numHelpful  reviews.rating  \
# 0                 806               5
# 1                 426               5
# 2                 295               5
# 3                   0               5
# 4                   3               5
#
#                                         reviews.text  \
# 0  IMPORTANT UPDATE (3/8/17): As you read my orig...
# 1  It was just a few weeks ago that I was bemoani...
# 2  The Amazon Tap is a portable Bluetooth speaker...
# 3  Look at this product as a portable speaker fir...
# 4  This Amazon tap is not only a great Bluetooth ...
#
#                                        reviews.title
# 0           The Echo's Little Sister Is AMAZING!! 3,
# 1                               Tap Alexa on the go!
# 2  Amazon Tap Review - Best Bluetooth Speaker in ...
# 3                             Great for what it does
# 4             Awesome, smart little portable speaker

# %%
df.columns
# Out:
# Index(['asins', 'name', 'reviews.numHelpful', 'reviews.rating', 'reviews.text',
#        'reviews.title'],
#       dtype='object')

# %%
reviews = df['reviews.text'].values

# %%
reviews[3]
# Out:
# 'Look at this product as a portable speaker first and an Echo replacement second. The big reason to buy this over standard Bluetooth speakers is this has WiFi streaming enabled. When you are at home you can stream music with ease to it. Voice recognition is top notch and it really shines when using it with other smart home accessories. The only problem is having to tap the microphone button for it to listen to your voice. If you want bigger sound and always listening features, spend the extra money on the Amazon Echo.'

# %%
len(reviews)
# Out:
# 542

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
sent_tokenize(reviews[3])
# Out:
# ['Look at this product as a portable speaker first and an Echo replacement second.',
#  'The big reason to buy this over standard Bluetooth speakers is this has WiFi streaming enabled.',
#  'When you are at home you can stream music with ease to it.',
#  'Voice recognition is top notch and it really shines when using it with other smart home accessories.',
#  'The only problem is having to tap the microphone button for it to listen to your voice.',
#  'If you want bigger sound and always listening features, spend the extra money on the Amazon Echo.']

# %%
review_sents=[sent_tokenize(review) for review in reviews]

# %%
review_sents[3]
# Out:
# ['Look at this product as a portable speaker first and an Echo replacement second.',
#  'The big reason to buy this over standard Bluetooth speakers is this has WiFi streaming enabled.',
#  'When you are at home you can stream music with ease to it.',
#  'Voice recognition is top notch and it really shines when using it with other smart home accessories.',
#  'The only problem is having to tap the microphone button for it to listen to your voice.',
#  'If you want bigger sound and always listening features, spend the extra money on the Amazon Echo.']

# %%
word_tokenize(review_sents[3][0])
# Out:
# ['Look',
#  'at',
#  'this',
#  'product',
#  'as',
#  'a',
#  'portable',
#  'speaker',
#  'first',
#  'and',
#  'an',
#  'Echo',
#  'replacement',
#  'second',
#  '.']

# %%
token_list= []
for review in review_sents:
  for sentence in reviews:
    token_list.append(word_tokenize(sentence))

# %%
len(token_list)
# Out:
# 293764

# %%
token_list[3]
# Out:
# ['Look',
#  'at',
#  'this',
#  'product',
#  'as',
#  'a',
#  'portable',
#  'speaker',
#  'first',
#  'and',
#  'an',
#  'Echo',
#  'replacement',
#  'second',
#  '.',
#  'The',
#  'big',
#  'reason',
#  'to',
#  'buy',
#  'this',
#  'over',
#  'standard',
#  'Bluetooth',
#  'speakers',
#  'is',
#  'this',
#  'has',
#  'WiFi',
#  'streaming',
#  'enabled',
#  '.',
#  'When',
#  'you',
#  'are',
#  'at',
#  'home',
#  'you',
#  'can',
#  'stream',
#  'music',
#  'with',
#  'ease',
#  'to',
#  'it',
#  '.',
#  'Voice',
#  'recognition',
#  'is',
#  'top',
#  'notch',
#  'and',
#  'it',
#  'really',
#  'shines',
#  'when',
#  'using',
#  'it',
#  'with',
#  'other',
#  'smart',
#  'home',
#  'accessories',
#  '.',
#  'The',
#  'only',
#  'problem',
#  'is',
#  'having',
#  'to',
#  'tap',
#  'the',
#  'microphone',
#  'button',
#  'for',
#  'it',
#  'to',
#  'listen',
#  'to',
#  'your',
#  'voice',
#  '.',
#  'If',
#  'you',
#  'want',
#  'bigger',
#  'sound',
#  'and',
#  'always',
#  'listening',
#  'features',
#  ',',
#  'spend',
#  'the',
#  'extra',
#  'money',
#  'on',
#  'the',
#  'Amazon',
#  'Echo',
#  '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.pos_tag(token_list[2])
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('The', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('portable', 'JJ'),
#  ('Bluetooth', 'NNP'),
#  ('speaker', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('controlled', 'VBN'),
#  ('with', 'IN'),
#  ('your', 'PRP$'),
#  ('voice', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('can', 'MD'),
#  ('instruct', 'VB'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('play', 'VB'),
#  ('music', 'NN'),
#  (',', ','),
#  ('order', 'NN'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('services', 'NNS'),
#  (',', ','),
#  ('control', 'NN'),
#  ('home', 'NN'),
#  ('automation', 'NN'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('connected', 'JJ'),
#  ('devices', 'NNS'),
#  (',', ','),
#  ('plus', 'CC'),
#  ('a', 'DT'),
#  ('whole', 'JJ'),
#  ('lot', 'NN'),
#  ('more.It', 'NN'),
#  ('contains', 'VBZ'),
#  ('a', 'DT'),
#  ('button', 'NN'),
#  ('activated', 'VBD'),
#  ('microphone', 'NN'),
#  ('for', 'IN'),
#  ('listening', 'VBG'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('verbal', 'JJ'),
#  ('commands', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('also', 'RB'),
#  ('has', 'VBZ'),
#  ('Dolby', 'NNP'),
#  ('stereo', 'NN'),
#  ('speakers', 'NNS'),
#  ('for', 'IN'),
#  ('playing', 'VBG'),
#  ('music', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('is', 'VBZ'),
#  ('basically', 'RB'),
#  ('the', 'DT'),
#  ('portable', 'JJ'),
#  ('version', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('popular', 'JJ'),
#  ('Amazon', 'NNP'),
#  ('Echo', 'NNP'),
#  ('that', 'WDT'),
#  ('was', 'VBD'),
#  ('released', 'VBN'),
#  ('last', 'JJ'),
#  ('year.Ive', 'NN'),
#  ('been', 'VBN'),
#  ('testing', 'VBG'),
#  ('the', 'DT'),
#  ('Tap', 'NNP'),
#  ('for', 'IN'),
#  ('several', 'JJ'),
#  ('days', 'NNS'),
#  ('now', 'RB'),
#  ('.', '.'),
#  ('Heres', 'VBZ'),
#  ('what', 'WP'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  (':', ':'),
#  ('What', 'WP'),
#  ('I', 'PRP'),
#  ('Like', 'IN'),
#  ('I', 'PRP'),
#  ('find', 'VBP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('Tap', 'NNP'),
#  ('understands', 'NNS'),
#  ('my', 'PRP$'),
#  ('verbal', 'JJ'),
#  ('commands', 'NNS'),
#  ('accurately', 'RB'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('could', 'MD'),
#  ('be', 'VB'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  (',', ','),
#  ('since', 'IN'),
#  ('its', 'PRP$'),
#  ('button', 'NN'),
#  ('activated', 'VBN'),
#  (',', ','),
#  ('Im', 'NNP'),
#  ('always', 'RB'),
#  ('very', 'RB'),
#  ('close', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('device', 'NN'),
#  ('when', 'WRB'),
#  ('I', 'PRP'),
#  ('speak', 'VBP'),
#  ('to', 'TO'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('Nevertheless', 'RB'),
#  (',', ','),
#  ('its', 'PRP$'),
#  ('nice', 'JJ'),
#  ('that', 'IN'),
#  ('Tap', 'NNP'),
#  ('understands', 'VBZ'),
#  ('me', 'PRP'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('was', 'VBD'),
#  ('my', 'PRP$'),
#  ('experience', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Echo', 'NNP'),
#  ('as', 'IN'),
#  ('well.The', 'NN'),
#  ('audio', 'NN'),
#  ('is', 'VBZ'),
#  ('surprisingly', 'RB'),
#  ('good', 'JJ'),
#  ('for', 'IN'),
#  ('such', 'JJ'),
#  ('a', 'DT'),
#  ('small', 'JJ'),
#  ('device', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('test', 'VBP'),
#  ('portable', 'JJ'),
#  ('speakers', 'NNS'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('and', 'CC'),
#  ('Id', 'NNP'),
#  ('say', 'VBP'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('is', 'VBZ'),
#  ('as', 'RB'),
#  ('good', 'JJ'),
#  ('as', 'IN'),
#  ('or', 'CC'),
#  ('better', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('speakers', 'NNS'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('price', 'NN'),
#  ('range', 'NN'),
#  ('.', '.'),
#  ('Do', 'VBP'),
#  ("n't", 'RB'),
#  ('expect', 'VB'),
#  ('Bose', 'NNP'),
#  ('type', 'JJ'),
#  ('sound', 'NN'),
#  ('or', 'CC'),
#  ('deep', 'JJ'),
#  ('bass', 'NN'),
#  ('levels', 'NNS'),
#  (',', ','),
#  ('however.No', 'VBZ'),
#  ('other', 'JJ'),
#  ('portable', 'JJ'),
#  ('speaker', 'NN'),
#  ('device', 'NN'),
#  ('offers', 'NNS'),
#  ('voice', 'NN'),
#  ('control', 'NN'),
#  ('and', 'CC'),
#  ('Wi-Fi', 'NNP'),
#  ('streaming', 'NN'),
#  ('.', '.'),
#  ('Thus', 'VB'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('offers', 'VBZ'),
#  ('a', 'DT'),
#  ('tremendous', 'JJ'),
#  ('amount', 'NN'),
#  ('of', 'IN'),
#  ('value', 'NN'),
#  ('over', 'IN'),
#  ('similarly', 'RB'),
#  ('priced', 'VBN'),
#  ('portable', 'JJ'),
#  ('speakers', 'NNS'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('especially', 'RB'),
#  ('true', 'JJ'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('already', 'RB'),
#  ('have', 'VBP'),
#  ('Amazon', 'NNP'),
#  ('Prime', 'NNP'),
#  ('and', 'CC'),
#  ('Prime', 'NNP'),
#  ('Music.It', 'NNP'),
#  ('supports', 'VBZ'),
#  ('many', 'JJ'),
#  ('great', 'JJ'),
#  ('services', 'NNS'),
#  ('.', '.'),
#  ('Like', 'IN'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Echo', 'NNP'),
#  ('that', 'WDT'),
#  ('came', 'VBD'),
#  ('before', 'IN'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('supports', 'VBZ'),
#  ('popular', 'JJ'),
#  ('music', 'NN'),
#  ('services', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('Prime', 'NNP'),
#  ('Music', 'NNP'),
#  (',', ','),
#  ('Spotify', 'NNP'),
#  (',', ','),
#  ('Pandora', 'NNP'),
#  (',', ','),
#  ('iHeartRadio', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('TuneIn.Battery', 'NNP'),
#  ('life', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('good', 'JJ'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('used', 'VBD'),
#  ('it', 'PRP'),
#  ('off', 'RP'),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('couple', 'JJ'),
#  ('days', 'NNS'),
#  ('without', 'IN'),
#  ('charging', 'VBG'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('Ill', 'NNP'),
#  ('post', 'VBD'),
#  ('an', 'DT'),
#  ('update', 'JJ'),
#  ('once', 'NN'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('come', 'VBN'),
#  ('closer', 'RBR'),
#  ('to', 'TO'),
#  ('testing', 'VBG'),
#  ('the', 'DT'),
#  ('limits', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('battery', 'NN'),
#  ('life.Read', 'NN'),
#  ('more', 'RBR')]

# %%
reviews_pos=[]
for sentence in token_list:
  reviews_pos.append(nltk.pos_tag(sentence))

# %%
reviews_pos[2]
# Out:
# [('The', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('portable', 'JJ'),
#  ('Bluetooth', 'NNP'),
#  ('speaker', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('be', 'VB'),
#  ('controlled', 'VBN'),
#  ('with', 'IN'),
#  ('your', 'PRP$'),
#  ('voice', 'NN'),
#  ('.', '.'),
#  ('You', 'PRP'),
#  ('can', 'MD'),
#  ('instruct', 'VB'),
#  ('it', 'PRP'),
#  ('to', 'TO'),
#  ('play', 'VB'),
#  ('music', 'NN'),
#  (',', ','),
#  ('order', 'NN'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('services', 'NNS'),
#  (',', ','),
#  ('control', 'NN'),
#  ('home', 'NN'),
#  ('automation', 'NN'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('connected', 'JJ'),
#  ('devices', 'NNS'),
#  (',', ','),
#  ('plus', 'CC'),
#  ('a', 'DT'),
#  ('whole', 'JJ'),
#  ('lot', 'NN'),
#  ('more.It', 'NN'),
#  ('contains', 'VBZ'),
#  ('a', 'DT'),
#  ('button', 'NN'),
#  ('activated', 'VBD'),
#  ('microphone', 'NN'),
#  ('for', 'IN'),
#  ('listening', 'VBG'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('verbal', 'JJ'),
#  ('commands', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('also', 'RB'),
#  ('has', 'VBZ'),
#  ('Dolby', 'NNP'),
#  ('stereo', 'NN'),
#  ('speakers', 'NNS'),
#  ('for', 'IN'),
#  ('playing', 'VBG'),
#  ('music', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('is', 'VBZ'),
#  ('basically', 'RB'),
#  ('the', 'DT'),
#  ('portable', 'JJ'),
#  ('version', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('popular', 'JJ'),
#  ('Amazon', 'NNP'),
#  ('Echo', 'NNP'),
#  ('that', 'WDT'),
#  ('was', 'VBD'),
#  ('released', 'VBN'),
#  ('last', 'JJ'),
#  ('year.Ive', 'NN'),
#  ('been', 'VBN'),
#  ('testing', 'VBG'),
#  ('the', 'DT'),
#  ('Tap', 'NNP'),
#  ('for', 'IN'),
#  ('several', 'JJ'),
#  ('days', 'NNS'),
#  ('now', 'RB'),
#  ('.', '.'),
#  ('Heres', 'VBZ'),
#  ('what', 'WP'),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  (':', ':'),
#  ('What', 'WP'),
#  ('I', 'PRP'),
#  ('Like', 'IN'),
#  ('I', 'PRP'),
#  ('find', 'VBP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('Tap', 'NNP'),
#  ('understands', 'NNS'),
#  ('my', 'PRP$'),
#  ('verbal', 'JJ'),
#  ('commands', 'NNS'),
#  ('accurately', 'RB'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('could', 'MD'),
#  ('be', 'VB'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('fact', 'NN'),
#  ('that', 'IN'),
#  (',', ','),
#  ('since', 'IN'),
#  ('its', 'PRP$'),
#  ('button', 'NN'),
#  ('activated', 'VBN'),
#  (',', ','),
#  ('Im', 'NNP'),
#  ('always', 'RB'),
#  ('very', 'RB'),
#  ('close', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('device', 'NN'),
#  ('when', 'WRB'),
#  ('I', 'PRP'),
#  ('speak', 'VBP'),
#  ('to', 'TO'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('Nevertheless', 'RB'),
#  (',', ','),
#  ('its', 'PRP$'),
#  ('nice', 'JJ'),
#  ('that', 'IN'),
#  ('Tap', 'NNP'),
#  ('understands', 'VBZ'),
#  ('me', 'PRP'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('was', 'VBD'),
#  ('my', 'PRP$'),
#  ('experience', 'NN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Echo', 'NNP'),
#  ('as', 'IN'),
#  ('well.The', 'NN'),
#  ('audio', 'NN'),
#  ('is', 'VBZ'),
#  ('surprisingly', 'RB'),
#  ('good', 'JJ'),
#  ('for', 'IN'),
#  ('such', 'JJ'),
#  ('a', 'DT'),
#  ('small', 'JJ'),
#  ('device', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('test', 'VBP'),
#  ('portable', 'JJ'),
#  ('speakers', 'NNS'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  ('and', 'CC'),
#  ('Id', 'NNP'),
#  ('say', 'VBP'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('is', 'VBZ'),
#  ('as', 'RB'),
#  ('good', 'JJ'),
#  ('as', 'IN'),
#  ('or', 'CC'),
#  ('better', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('speakers', 'NNS'),
#  ('in', 'IN'),
#  ('its', 'PRP$'),
#  ('price', 'NN'),
#  ('range', 'NN'),
#  ('.', '.'),
#  ('Do', 'VBP'),
#  ("n't", 'RB'),
#  ('expect', 'VB'),
#  ('Bose', 'NNP'),
#  ('type', 'JJ'),
#  ('sound', 'NN'),
#  ('or', 'CC'),
#  ('deep', 'JJ'),
#  ('bass', 'NN'),
#  ('levels', 'NNS'),
#  (',', ','),
#  ('however.No', 'VBZ'),
#  ('other', 'JJ'),
#  ('portable', 'JJ'),
#  ('speaker', 'NN'),
#  ('device', 'NN'),
#  ('offers', 'NNS'),
#  ('voice', 'NN'),
#  ('control', 'NN'),
#  ('and', 'CC'),
#  ('Wi-Fi', 'NNP'),
#  ('streaming', 'NN'),
#  ('.', '.'),
#  ('Thus', 'VB'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('offers', 'VBZ'),
#  ('a', 'DT'),
#  ('tremendous', 'JJ'),
#  ('amount', 'NN'),
#  ('of', 'IN'),
#  ('value', 'NN'),
#  ('over', 'IN'),
#  ('similarly', 'RB'),
#  ('priced', 'VBN'),
#  ('portable', 'JJ'),
#  ('speakers', 'NNS'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('especially', 'RB'),
#  ('true', 'JJ'),
#  ('if', 'IN'),
#  ('you', 'PRP'),
#  ('already', 'RB'),
#  ('have', 'VBP'),
#  ('Amazon', 'NNP'),
#  ('Prime', 'NNP'),
#  ('and', 'CC'),
#  ('Prime', 'NNP'),
#  ('Music.It', 'NNP'),
#  ('supports', 'VBZ'),
#  ('many', 'JJ'),
#  ('great', 'JJ'),
#  ('services', 'NNS'),
#  ('.', '.'),
#  ('Like', 'IN'),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Echo', 'NNP'),
#  ('that', 'WDT'),
#  ('came', 'VBD'),
#  ('before', 'IN'),
#  ('it', 'PRP'),
#  (',', ','),
#  ('the', 'DT'),
#  ('Amazon', 'NNP'),
#  ('Tap', 'NNP'),
#  ('supports', 'VBZ'),
#  ('popular', 'JJ'),
#  ('music', 'NN'),
#  ('services', 'NNS'),
#  ('such', 'JJ'),
#  ('as', 'IN'),
#  ('Prime', 'NNP'),
#  ('Music', 'NNP'),
#  (',', ','),
#  ('Spotify', 'NNP'),
#  (',', ','),
#  ('Pandora', 'NNP'),
#  (',', ','),
#  ('iHeartRadio', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('TuneIn.Battery', 'NNP'),
#  ('life', 'NN'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('good', 'JJ'),
#  ('so', 'RB'),
#  ('far', 'RB'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('used', 'VBD'),
#  ('it', 'PRP'),
#  ('off', 'RP'),
#  ('and', 'CC'),
#  ('on', 'IN'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('couple', 'JJ'),
#  ('days', 'NNS'),
#  ('without', 'IN'),
#  ('charging', 'VBG'),
#  ('it', 'PRP'),
#  ('.', '.'),
#  ('Ill', 'NNP'),
#  ('post', 'VBD'),
#  ('an', 'DT'),
#  ('update', 'JJ'),
#  ('once', 'NN'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('come', 'VBN'),
#  ('closer', 'RBR'),
#  ('to', 'TO'),
#  ('testing', 'VBG'),
#  ('the', 'DT'),
#  ('limits', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('battery', 'NN'),
#  ('life.Read', 'NN'),
#  ('more', 'RBR')]

# %%
[word for word,tag in reviews_pos[2] if tag.startswith ("NN")]
# Out:
# ['Amazon',
#  'Tap',
#  'Bluetooth',
#  'speaker',
#  'voice',
#  'music',
#  'order',
#  'products',
#  'services',
#  'control',
#  'home',
#  'automation',
#  'products',
#  'devices',
#  'lot',
#  'more.It',
#  'button',
#  'microphone',
#  'commands',
#  'Dolby',
#  'stereo',
#  'speakers',
#  'music',
#  'Amazon',
#  'Tap',
#  'version',
#  'Amazon',
#  'Echo',
#  'year.Ive',
#  'Tap',
#  'days',
#  'Tap',
#  'understands',
#  'commands',
#  'fact',
#  'button',
#  'Im',
#  'device',
#  'Tap',
#  'time',
#  'experience',
#  'Amazon',
#  'Echo',
#  'well.The',
#  'audio',
#  'device',
#  'speakers',
#  'time',
#  'Id',
#  'Amazon',
#  'Tap',
#  'speakers',
#  'price',
#  'range',
#  'Bose',
#  'sound',
#  'bass',
#  'levels',
#  'speaker',
#  'device',
#  'offers',
#  'voice',
#  'control',
#  'Wi-Fi',
#  'streaming',
#  'Amazon',
#  'Tap',
#  'amount',
#  'value',
#  'speakers',
#  'Amazon',
#  'Prime',
#  'Prime',
#  'Music.It',
#  'services',
#  'Amazon',
#  'Echo',
#  'Amazon',
#  'Tap',
#  'music',
#  'services',
#  'Prime',
#  'Music',
#  'Spotify',
#  'Pandora',
#  'iHeartRadio',
#  'TuneIn.Battery',
#  'life',
#  'days',
#  'Ill',
#  'once',
#  'limits',
#  'battery',
#  'life.Read']

# %%
all_nouns_list = []
for sentence in reviews_pos:
  all_nouns_list.extend([word for word,tag in sentence if tag.startswith("NN")])

# %%
all_nouns_list
# Out:
# ['IMPORTANT',
#  'UPDATE',
#  'review',
#  'please',
#  'Amazon',
#  'February',
#  'firmware',
#  'update',
#  'Amazon',
#  'Tap',
#  'owners',
#  'option',
#  'Settings',
#  'Alexa',
#  'app',
#  'option',
#  'Tap',
#  'respond',
#  'commands',
#  'Echo',
#  'Echo',
#  'Dot',
#  'development',
#  'something',
#  'Tap',
#  'owners',
#  'Thank',
#  'lack',
#  'operation',
#  'shortcoming',
#  'Tap',
#  'device',
#  'lot',
#  'thing',
#  'mind',
#  'Tap',
#  'battery',
#  'power',
#  'mode',
#  'battery',
#  'microphone',
#  'times',
#  'tap',
#  'mode',
#  'Alexa',
#  'app',
#  'Tap',
#  'battery',
#  'life',
#  'convenience.',
#  'Amazon',
#  'Echo',
#  'device',
#  'anyway',
#  'days',
#  'Echo',
#  'demand',
#  'risk',
#  'Today',
#  'music',
#  'listener',
#  'Echo',
#  'try.I',
#  'device',
#  'music',
#  'kitchen',
#  'Echos',
#  'voice',
#  'control',
#  'question',
#  'Echo.Read',
#  'weeks',
#  'fact',
#  'Echo',
#  'year',
#  'price',
#  'voice',
#  'remote',
#  'year',
#  'device',
#  'year',
#  'game',
#  'Echo',
#  'Tap',
#  'things',
#  'Echo',
#  'Alexa',
#  'devices',
#  'try.I',
#  'years',
#  'home',
#  'combination',
#  'Smartthings',
#  'IFTTT',
#  'Logitech',
#  'Harmony',
#  'home',
#  'Alexa',
#  'middle',
#  'ability',
#  'home',
#  'voice',
#  'killer',
#  'feature',
#  'parts',
#  'home',
#  'control',
#  'Echo/Tap',
#  'house',
#  'setup.Read',
#  'Amazon',
#  'Tap',
#  'Bluetooth',
#  'speaker',
#  'voice',
#  'music',
#  'order',
#  'products',
#  'services',
#  'control',
#  'home',
#  'automation',
#  'products',
#  'devices',
#  'lot',
#  'more.It',
#  'button',
#  'microphone',
#  'commands',
#  'Dolby',
#  'stereo',
#  'speakers',
#  'music',
#  'Amazon',
#  'Tap',
#  'version',
#  'Amazon',
#  'Echo',
#  'year.Ive',
#  'Tap',
#  'days',
#  'Tap',
#  'understands',
#  'commands',
#  'fact',
#  'button',
#  'Im',
#  'device',
#  'Tap',
#  'time',
#  'experience',
#  'Amazon',
#  'Echo',
#  'well.The',
#  'audio',
#  'device',
#  'speakers',
#  'time',
#  'Id',
#  'Amazon',
#  'Tap',
#  'speakers',
#  'price',
#  'range',
#  'Bose',
#  'sound',
#  'bass',
#  'levels',
#  'speaker',
#  'device',
#  'offers',
#  'voice',
#  'control',
#  'Wi-Fi',
#  'streaming',
#  'Amazon',
#  'Tap',
#  'amount',
#  'value',
#  'speakers',
#  'Amazon',
#  'Prime',
#  'Prime',
#  'Music.It',
#  'services',
#  'Amazon',
#  'Echo',
#  'Amazon',
#  'Tap',
#  'music',
#  'services',
#  'Prime',
#  'Music',
#  'Spotify',
#  'Pandora',
#  'iHeartRadio',
#  'TuneIn.Battery',
#  'life',
#  'days',
#  'Ill',
#  'once',
#  'limits',
#  'battery',
#  'life.Read',
#  'Look',
#  'product',
#  'speaker',
#  'Echo',
#  'replacement',
#  'second',
#  'reason',
#  'Bluetooth',
#  'speakers',
#  'home',
#  'music',
#  'ease',
#  'Voice',
#  'recognition',
#  'notch',
#  'home',
#  'accessories',
#  'problem',
#  'microphone',
#  'button',
#  'voice',
#  'sound',
#  'features',
#  'money',
#  'Amazon',
#  'Echo',
#  'Amazon',
#  'tap',
#  'Bluetooth',
#  'speaker',
#  'half',
#  'reason',
#  'voice',
#  'control',
#  'wemo',
#  'switch',
#  'lamp',
#  'commands',
#  'ittt',
#  'minutes',
#  'Amazon',
#  'tap',
#  'lamp',
#  'Pretty',
#  'Amazon',
#  'tap',
#  'dock',
#  'cables',
#  'hour',
#  'battery',
#  'life',
#  'day',
#  'Google',
#  'play',
#  'music',
#  'thing',
#  'speaker',
#  'IMO',
#  'way',
#  'Google',
#  'play',
#  'music',
#  'device',
#  'Alexa',
#  'iHeartRadio',
#  'Pandora',
#  'Spotify',
#  'music',
#  'Apple',
#  'iTunes',
#  'love',
#  'Google',
#  'play',
#  'music',
#  'Amazon',
#  'dollars',
#  'month',
#  'family',
#  'plan',
#  'family',
#  'members',
#  'access',
#  'Google',
#  'play',
#  'music',
#  'YouTube',
#  'tap',
#  'Amazon',
#  'tap',
#  'Bluetooth',
#  'speaker',
#  'phone',
#  'streaming',
#  'device',
#  'phone',
#  'port',
#  'speaker',
#  'everything',
#  'Bluetooth',
#  'speaker',
#  'market',
#  'bit',
#  'Bought',
#  'Deal',
#  'Day',
#  'Best',
#  'Buy',
#  'Just',
#  'button',
#  'something',
#  'play',
#  'radio',
#  'station',
#  'music',
#  'play',
#  'list',
#  'set',
#  'timers',
#  'alarms',
#  'half',
#  'features',
#  'TAP',
#  'sound',
#  'device',
#  'Sound',
#  'product',
#  'Nothing',
#  'Echo',
#  'year',
#  'features',
#  'Tap',
#  'hands',
#  'feature',
#  'Echo',
#  'portability',
#  'outdoors',
#  'home',
#  'WiFi',
#  'play',
#  'music',
#  'features',
#  'Alexa',
#  'unit',
#  'cradle',
#  'Tap',
#  'news',
#  'weather',
#  'music',
#  'items',
#  'Amazon',
#  'connectivity',
#  'problems',
#  'wifi',
#  'taps',
#  'fault',
#  'wifi',
#  'purchase',
#  'sounds',
#  'voice',
#  'commands',
#  'versions',
#  'echo',
#  'dot',
#  'tap',
#  'versatile',
#  'wireless',
#  'recharging',
#  'sound',
#  'portability',
#  'buy',
#  'speaker',
#  'sound',
#  'quality',
#  'ability',
#  'phone/tablet',
#  'Bluetooth',
#  'speakers',
#  'phone',
#  'music',
#  'sound',
#  'quality',
#  'sale',
#  'sound',
#  'account',
#  'access',
#  'music',
#  'echo',
#  'tap',
#  'products',
#  'lights',
#  'locks',
#  'music',
#  'house',
#  'option',
#  'button',
#  'surprise',
#  'Tap',
#  'Echo',
#  'house',
#  'Alexa',
#  'device',
#  'tap',
#  'Amazon',
#  'hardware',
#  'year',
#  'Amazon',
#  'mode',
#  'Echo',
#  'microphones.Sound',
#  'quality',
#  'speaker',
#  'Battery',
#  'life',
#  'implementation',
#  'Alexa',
#  'time',
#  'Tap',
#  'music',
#  'weather',
#  'device',
#  'space',
#  'kitchen',
#  'end',
#  'Bluetooth',
#  'speakers',
#  'Amazon',
#  'tap',
#  'rates',
#  'sound',
#  'quality',
#  'everyone',
#  'family',
#  'share',
#  'problem',
#  'friend',
#  'Great',
#  'product',
#  'intro',
#  'AI',
#  'device',
#  'wait',
#  'reasons',
#  'staff',
#  'gift',
#  'Might',
#  'lol',
#  'everything',
#  'sound',
#  'base',
#  'room',
#  'music',
#  'Was',
#  'product',
#  'sheer',
#  'portability',
#  'outlet',
#  'time',
#  'Echo',
#  'Dot',
#  'sound',
#  'quality',
#  'volume',
#  'speaker',
#  'mode',
#  'feature',
#  'battery',
#  'faster',
#  'Amazon',
#  'dot',
#  'tap',
#  'sale',
#  'sound',
#  'rate',
#  'Amazon',
#  'Tap',
#  'stars',
#  'application',
#  'Alexa',
#  'command',
#  'button',
#  'unit',
#  'Alexas',
#  'house',
#  'speaker',
#  'product',
#  'ease',
#  'use',
#  'purchases',
#  'music',
#  'radio',
#  'kitchen',
#  'smarter',
#  'product',
#  'trips',
#  'option',
#  'music',
#  'garage',
#  'battery',
#  'Never',
#  'issue',
#  'juice',
#  'issue',
#  'mics',
#  'voice',
#  'Echo',
#  'Dot',
#  'Alexa',
#  'command',
#  'speaker',
#  'features',
#  'Amazon',
#  'job',
#  'inna',
#  'package',
#  'music',
#  'Amazon',
#  'Prime',
#  'Pandora',
#  'device',
#  'Google',
#  'Home',
#  'Great',
#  'concept',
#  'speaker',
#  'volume',
#  'updates',
#  'item',
#  'beginning',
#  'request',
#  'commands',
#  'fact',
#  'items',
#  'inventions',
#  'Alexa',
#  'songs',
#  'Amazon',
#  'Tap',
#  'addition',
#  'Smarthome',
#  'system',
#  'room',
#  'room',
#  'AC',
#  'battery',
#  'time',
#  'music',
#  'Amazon',
#  'Prime',
#  'Spotify',
#  'Amazon',
#  'speaker',
#  'annoyance',
#  'Alexa',
#  'wake',
#  'word',
#  'command',
#  'echos',
#  'way',
#  'off',
#  'echo',
#  'fort',
#  'son',
#  'room',
#  'user',
#  'Great',
#  'value',
#  'quality',
#  'speaker',
#  'information',
#  'highway',
#  'gift',
#  'father',
#  'purchase',
#  'speaker',
#  'family',
#  'favorite',
#  'portability',
#  'music',
#  'streaming',
#  'kids',
#  'Alexa',
#  'DJ',
#  'Amazon',
#  'Prime',
#  'Unlimited',
#  'Music',
#  'program',
#  'Battery',
#  'life',
#  'quality',
#  'purposes',
#  'audiophiles',
#  'lack',
#  'bass',
#  'job',
#  'family',
#  'software',
#  'hardware',
#  'machine',
#  'Echo',
#  'connectivity',
#  'issues',
#  'features',
#  'portability',
#  'battery',
#  'life',
#  'connectivity',
#  'issues',
#  'reviews',
#  'purchasing',
#  'one',
#  'way',
#  'sound',
#  'Amazon',
#  'Tap',
#  'Bluetooth',
#  'wireless',
#  'speaker',
#  'brother',
#  'fave',
#  'tunes',
#  'pool',
#  'charge',
#  'hours',
#  'listening',
#  'echo',
#  'music',
#  'weather',
#  'anything',
#  'house',
#  'product',
#  'home',
#  'one',
#  'things',
#  'tap',
#  'deck',
#  'cup',
#  'coffee',
#  'music',
#  'pandora',
#  'radio',
#  'husband',
#  'i',
#  'mom',
#  'years',
#  'day',
#  'amazon',
#  'tap',
#  'i',
#  'draugther',
#  'dot',
#  'i',
#  'self',
#  'tap',
#  'i',
#  'tap',
#  'hands',
#  'button',
#  'kids',
#  'ganes',
#  'alexa',
#  'i',
#  'household',
#  'software',
#  'update',
#  'hands',
#  'mode',
#  'everything',
#  'Echo',
#  'speaker',
#  'device',
#  'everything',
#  'time',
#  'tap',
#  'mode',
#  'quality',
#  'speaker',
#  'size',
#  'choice',
#  'hotspot',
#  'data',
#  'Alexa',
#  'go',
#  'sound',
#  'Echo',
#  'price',
#  'Dot',
#  'Echo',
#  'Tap',
#  'Portable',
#  'rooms',
#  'music',
#  'patio',
#  'music',
#  'bass',
#  'sound',
#  'perfect',
#  'tunes',
#  'SiriusXM',
#  'Alexa',
#  'access',
#  'music',
#  'Howard',
#  'stern',
#  'NFL',
#  'MLB',
#  'rest',
#  'satellite',
#  'radio',
#  'content',
#  'thing',
#  'tap',
#  'Bluetooth',
#  'speaker',
#  'solo',
#  'Alexa',
#  'wifi',
#  'wife',
#  'learning',
#  'process',
#  'benefits',
#  'things',
#  'wife',
#  'commands',
#  'Hmmm',
#  'fun',
#  'convenient',
#  'toy',
#  'limitations',
#  'NPR',
#  'news',
#  'clip',
#  'news',
#  'news',
#  'news',
#  'highlights',
#  'music',
#  'Echo',
#  'songs',
#  'time',
#  'reviews',
#  'Amazon',
#  'echo',
#  'products',
#  'portability',
#  'size',
#  'Tap',
#  'product',
#  'expectations',
#  'day',
#  'music',
#  'questions',
#  'accent',
#  'problems',
#  'comments',
#  'Alexa',
#  'timers/alarms',
#  'lists',
#  'Tap',
#  'ability',
#  'room',
#  'room',
#  'patio',
#  'Thoughts',
#  'Echo',
#  'grow',
#  'list',
#  'tasks',
#  'app',
#  'smartphone',
#  'list',
#  'place',
#  'calls',
#  'Echo',
#  'Samsung',
#  'smartphone',
#  'Disappointed',
#  'fact',
#  'battery',
#  'issues',
#  'rooms',
#  'amount',
#  'Bass',
#  'size',
#  'Awesome',
#  'speaker',
#  'easy',
#  'Easy',
#  'Great',
#  'pool',
#  'features',
#  'Echo',
#  'house',
#  'w/you',
#  'Always',
#  'Amazon',
#  'Echo',
#  'wherever',
#  'Smaller',
#  'i',
#  'sounds',
#  'hands',
#  'button',
#  'penny',
#  'time',
#  'expectations',
#  'product',
#  'friends',
#  'family',
#  'Amazon',
#  'Tap',
#  'investment',
#  'Alexa',
#  'everyday',
#  'Love',
#  'someone',
#  'notes',
#  'music',
#  'demand',
#  'Bluetooth',
#  'speaker',
#  'Alexa',
#  'hands',
#  'things',
#  'quality',
#  'bathroom',
#  'issues',
#  'steam',
#  'Echo',
#  'fool',
#  'battery',
#  'everything',
#  'music',
#  'product',
#  'amazon',
#  'account',
#  'part',
#  'conversations',
#  'option',
#  'button',
#  'voice',
#  'command',
#  'way',
#  'till',
#  'Google',
#  'device',
#  'devices',
#  'Dot',
#  'Hate',
#  'Tap',
#  'Portable',
#  'device',
#  'charge',
#  'day',
#  'dots',
#  'tap',
#  'fun',
#  'music',
#  'relation',
#  'music',
#  'night',
#  'night',
#  'thing',
#  'speaker',
#  'assistance',
#  'Alexa',
#  'Was',
#  'Bluetooth',
#  'speaker',
#  'choice',
#  'needs',
#  'Great',
#  'speaker',
#  'sound',
#  'day',
#  'Alexa',
#  'network',
#  'Amazon',
#  'Tap',
#  'complement',
#  'Amazon',
#  'Echo',
#  'office',
#  'space',
#  'advantages',
#  'Echo',
#  'Bluetooth',
#  'speaker',
#  'button',
#  'Alexa',
#  'issue',
#  'Sound',
#  'quality',
#  'Bluetooth',
#  'speaker',
#  'market',
#  'Alexa',
#  'lots',
#  'things',
#  'Fun',
#  'family',
#  'product',
#  'grandkids',
#  'app',
#  'functionality',
#  'compatibility',
#  'speaker',
#  'feature',
#  'friend',
#  'Dot',
#  'devices',
#  'Echo',
#  'Tap',
#  'CNET',
#  'review',
#  'Tap',
#  'frustrations',
#  'wake',
#  'word',
#  'Alexis',
#  'language',
#  'service',
#  'book',
#  'member',
#  'addition',
#  'household',
#  'Guys',
#  'Tap',
#  'everything',
#  'Echo',
#  'home',
#  'everything',
#  'work',
#  'desk',
#  'music',
#  'weather',
#  'speaker',
#  'Great',
#  'sound',
#  'value',
#  'worlds',
#  'BT',
#  'speaker',
#  'Amazon',
#  'Alexa',
#  'device',
#  'anyone',
#  'BT',
#  'speaker',
#  'Alexa',
#  'device',
#  'hours',
#  'day',
#  'wemo-device',
#  'battery',
#  'life',
#  'quality',
#  'voice',
#  'recognition',
#  'Tap',
#  'Echo',
#  'deck',
#  'Tap',
#  'stand',
#  'bothering',
#  'Bluetooth',
#  'speakers',
#  'phone',
#  'music',
#  'Internet',
#  'TAP',
#  'sound',
#  'battery',
#  'WiFi',
#  'tooth',
#  'button',
#  'speaker',
#  'fact',
#  'bonus',
#  'Alex',
#  'update',
#  'button',
#  'name',
#  'echo',
#  'speaker',
#  'one',
#  'm',
#  'echo',
#  'booming',
#  'sound',
#  'stages',
#  'home',
#  'smartness',
#  'start',
#  'product',
#  'app',
#  ...]

# %%
len(all_nouns_list)
# Out:
# 2655258

# %%
from nltk.corpus import stopwords
from string import punctuation

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords_nltk = stopwords.words("english")
punc_list = list(punctuation)
final_word_removal=punc_list + stopwords_nltk

# %%
clean_nouns = [noun.lower() for noun in all_nouns_list if noun.lower() not in final_word_removal]

# %%
clean_nouns
# Out:
# ['important',
#  'update',
#  'review',
#  'please',
#  'amazon',
#  'february',
#  'firmware',
#  'update',
#  'amazon',
#  'tap',
#  'owners',
#  'option',
#  'settings',
#  'alexa',
#  'app',
#  'option',
#  'tap',
#  'respond',
#  'commands',
#  'echo',
#  'echo',
#  'dot',
#  'development',
#  'something',
#  'tap',
#  'owners',
#  'thank',
#  'lack',
#  'operation',
#  'shortcoming',
#  'tap',
#  'device',
#  'lot',
#  'thing',
#  'mind',
#  'tap',
#  'battery',
#  'power',
#  'mode',
#  'battery',
#  'microphone',
#  'times',
#  'tap',
#  'mode',
#  'alexa',
#  'app',
#  'tap',
#  'battery',
#  'life',
#  'convenience.',
#  'amazon',
#  'echo',
#  'device',
#  'anyway',
#  'days',
#  'echo',
#  'demand',
#  'risk',
#  'today',
#  'music',
#  'listener',
#  'echo',
#  'try.i',
#  'device',
#  'music',
#  'kitchen',
#  'echos',
#  'voice',
#  'control',
#  'question',
#  'echo.read',
#  'weeks',
#  'fact',
#  'echo',
#  'year',
#  'price',
#  'voice',
#  'remote',
#  'year',
#  'device',
#  'year',
#  'game',
#  'echo',
#  'tap',
#  'things',
#  'echo',
#  'alexa',
#  'devices',
#  'try.i',
#  'years',
#  'home',
#  'combination',
#  'smartthings',
#  'ifttt',
#  'logitech',
#  'harmony',
#  'home',
#  'alexa',
#  'middle',
#  'ability',
#  'home',
#  'voice',
#  'killer',
#  'feature',
#  'parts',
#  'home',
#  'control',
#  'echo/tap',
#  'house',
#  'setup.read',
#  'amazon',
#  'tap',
#  'bluetooth',
#  'speaker',
#  'voice',
#  'music',
#  'order',
#  'products',
#  'services',
#  'control',
#  'home',
#  'automation',
#  'products',
#  'devices',
#  'lot',
#  'more.it',
#  'button',
#  'microphone',
#  'commands',
#  'dolby',
#  'stereo',
#  'speakers',
#  'music',
#  'amazon',
#  'tap',
#  'version',
#  'amazon',
#  'echo',
#  'year.ive',
#  'tap',
#  'days',
#  'tap',
#  'understands',
#  'commands',
#  'fact',
#  'button',
#  'im',
#  'device',
#  'tap',
#  'time',
#  'experience',
#  'amazon',
#  'echo',
#  'well.the',
#  'audio',
#  'device',
#  'speakers',
#  'time',
#  'id',
#  'amazon',
#  'tap',
#  'speakers',
#  'price',
#  'range',
#  'bose',
#  'sound',
#  'bass',
#  'levels',
#  'speaker',
#  'device',
#  'offers',
#  'voice',
#  'control',
#  'wi-fi',
#  'streaming',
#  'amazon',
#  'tap',
#  'amount',
#  'value',
#  'speakers',
#  'amazon',
#  'prime',
#  'prime',
#  'music.it',
#  'services',
#  'amazon',
#  'echo',
#  'amazon',
#  'tap',
#  'music',
#  'services',
#  'prime',
#  'music',
#  'spotify',
#  'pandora',
#  'iheartradio',
#  'tunein.battery',
#  'life',
#  'days',
#  'ill',
#  'limits',
#  'battery',
#  'life.read',
#  'look',
#  'product',
#  'speaker',
#  'echo',
#  'replacement',
#  'second',
#  'reason',
#  'bluetooth',
#  'speakers',
#  'home',
#  'music',
#  'ease',
#  'voice',
#  'recognition',
#  'notch',
#  'home',
#  'accessories',
#  'problem',
#  'microphone',
#  'button',
#  'voice',
#  'sound',
#  'features',
#  'money',
#  'amazon',
#  'echo',
#  'amazon',
#  'tap',
#  'bluetooth',
#  'speaker',
#  'half',
#  'reason',
#  'voice',
#  'control',
#  'wemo',
#  'switch',
#  'lamp',
#  'commands',
#  'ittt',
#  'minutes',
#  'amazon',
#  'tap',
#  'lamp',
#  'pretty',
#  'amazon',
#  'tap',
#  'dock',
#  'cables',
#  'hour',
#  'battery',
#  'life',
#  'day',
#  'google',
#  'play',
#  'music',
#  'thing',
#  'speaker',
#  'imo',
#  'way',
#  'google',
#  'play',
#  'music',
#  'device',
#  'alexa',
#  'iheartradio',
#  'pandora',
#  'spotify',
#  'music',
#  'apple',
#  'itunes',
#  'love',
#  'google',
#  'play',
#  'music',
#  'amazon',
#  'dollars',
#  'month',
#  'family',
#  'plan',
#  'family',
#  'members',
#  'access',
#  'google',
#  'play',
#  'music',
#  'youtube',
#  'tap',
#  'amazon',
#  'tap',
#  'bluetooth',
#  'speaker',
#  'phone',
#  'streaming',
#  'device',
#  'phone',
#  'port',
#  'speaker',
#  'everything',
#  'bluetooth',
#  'speaker',
#  'market',
#  'bit',
#  'bought',
#  'deal',
#  'day',
#  'best',
#  'buy',
#  'button',
#  'something',
#  'play',
#  'radio',
#  'station',
#  'music',
#  'play',
#  'list',
#  'set',
#  'timers',
#  'alarms',
#  'half',
#  'features',
#  'tap',
#  'sound',
#  'device',
#  'sound',
#  'product',
#  'nothing',
#  'echo',
#  'year',
#  'features',
#  'tap',
#  'hands',
#  'feature',
#  'echo',
#  'portability',
#  'outdoors',
#  'home',
#  'wifi',
#  'play',
#  'music',
#  'features',
#  'alexa',
#  'unit',
#  'cradle',
#  'tap',
#  'news',
#  'weather',
#  'music',
#  'items',
#  'amazon',
#  'connectivity',
#  'problems',
#  'wifi',
#  'taps',
#  'fault',
#  'wifi',
#  'purchase',
#  'sounds',
#  'voice',
#  'commands',
#  'versions',
#  'echo',
#  'dot',
#  'tap',
#  'versatile',
#  'wireless',
#  'recharging',
#  'sound',
#  'portability',
#  'buy',
#  'speaker',
#  'sound',
#  'quality',
#  'ability',
#  'phone/tablet',
#  'bluetooth',
#  'speakers',
#  'phone',
#  'music',
#  'sound',
#  'quality',
#  'sale',
#  'sound',
#  'account',
#  'access',
#  'music',
#  'echo',
#  'tap',
#  'products',
#  'lights',
#  'locks',
#  'music',
#  'house',
#  'option',
#  'button',
#  'surprise',
#  'tap',
#  'echo',
#  'house',
#  'alexa',
#  'device',
#  'tap',
#  'amazon',
#  'hardware',
#  'year',
#  'amazon',
#  'mode',
#  'echo',
#  'microphones.sound',
#  'quality',
#  'speaker',
#  'battery',
#  'life',
#  'implementation',
#  'alexa',
#  'time',
#  'tap',
#  'music',
#  'weather',
#  'device',
#  'space',
#  'kitchen',
#  'end',
#  'bluetooth',
#  'speakers',
#  'amazon',
#  'tap',
#  'rates',
#  'sound',
#  'quality',
#  'everyone',
#  'family',
#  'share',
#  'problem',
#  'friend',
#  'great',
#  'product',
#  'intro',
#  'ai',
#  'device',
#  'wait',
#  'reasons',
#  'staff',
#  'gift',
#  'might',
#  'lol',
#  'everything',
#  'sound',
#  'base',
#  'room',
#  'music',
#  'product',
#  'sheer',
#  'portability',
#  'outlet',
#  'time',
#  'echo',
#  'dot',
#  'sound',
#  'quality',
#  'volume',
#  'speaker',
#  'mode',
#  'feature',
#  'battery',
#  'faster',
#  'amazon',
#  'dot',
#  'tap',
#  'sale',
#  'sound',
#  'rate',
#  'amazon',
#  'tap',
#  'stars',
#  'application',
#  'alexa',
#  'command',
#  'button',
#  'unit',
#  'alexas',
#  'house',
#  'speaker',
#  'product',
#  'ease',
#  'use',
#  'purchases',
#  'music',
#  'radio',
#  'kitchen',
#  'smarter',
#  'product',
#  'trips',
#  'option',
#  'music',
#  'garage',
#  'battery',
#  'never',
#  'issue',
#  'juice',
#  'issue',
#  'mics',
#  'voice',
#  'echo',
#  'dot',
#  'alexa',
#  'command',
#  'speaker',
#  'features',
#  'amazon',
#  'job',
#  'inna',
#  'package',
#  'music',
#  'amazon',
#  'prime',
#  'pandora',
#  'device',
#  'google',
#  'home',
#  'great',
#  'concept',
#  'speaker',
#  'volume',
#  'updates',
#  'item',
#  'beginning',
#  'request',
#  'commands',
#  'fact',
#  'items',
#  'inventions',
#  'alexa',
#  'songs',
#  'amazon',
#  'tap',
#  'addition',
#  'smarthome',
#  'system',
#  'room',
#  'room',
#  'ac',
#  'battery',
#  'time',
#  'music',
#  'amazon',
#  'prime',
#  'spotify',
#  'amazon',
#  'speaker',
#  'annoyance',
#  'alexa',
#  'wake',
#  'word',
#  'command',
#  'echos',
#  'way',
#  'echo',
#  'fort',
#  'son',
#  'room',
#  'user',
#  'great',
#  'value',
#  'quality',
#  'speaker',
#  'information',
#  'highway',
#  'gift',
#  'father',
#  'purchase',
#  'speaker',
#  'family',
#  'favorite',
#  'portability',
#  'music',
#  'streaming',
#  'kids',
#  'alexa',
#  'dj',
#  'amazon',
#  'prime',
#  'unlimited',
#  'music',
#  'program',
#  'battery',
#  'life',
#  'quality',
#  'purposes',
#  'audiophiles',
#  'lack',
#  'bass',
#  'job',
#  'family',
#  'software',
#  'hardware',
#  'machine',
#  'echo',
#  'connectivity',
#  'issues',
#  'features',
#  'portability',
#  'battery',
#  'life',
#  'connectivity',
#  'issues',
#  'reviews',
#  'purchasing',
#  'one',
#  'way',
#  'sound',
#  'amazon',
#  'tap',
#  'bluetooth',
#  'wireless',
#  'speaker',
#  'brother',
#  'fave',
#  'tunes',
#  'pool',
#  'charge',
#  'hours',
#  'listening',
#  'echo',
#  'music',
#  'weather',
#  'anything',
#  'house',
#  'product',
#  'home',
#  'one',
#  'things',
#  'tap',
#  'deck',
#  'cup',
#  'coffee',
#  'music',
#  'pandora',
#  'radio',
#  'husband',
#  'mom',
#  'years',
#  'day',
#  'amazon',
#  'tap',
#  'draugther',
#  'dot',
#  'self',
#  'tap',
#  'tap',
#  'hands',
#  'button',
#  'kids',
#  'ganes',
#  'alexa',
#  'household',
#  'software',
#  'update',
#  'hands',
#  'mode',
#  'everything',
#  'echo',
#  'speaker',
#  'device',
#  'everything',
#  'time',
#  'tap',
#  'mode',
#  'quality',
#  'speaker',
#  'size',
#  'choice',
#  'hotspot',
#  'data',
#  'alexa',
#  'go',
#  'sound',
#  'echo',
#  'price',
#  'dot',
#  'echo',
#  'tap',
#  'portable',
#  'rooms',
#  'music',
#  'patio',
#  'music',
#  'bass',
#  'sound',
#  'perfect',
#  'tunes',
#  'siriusxm',
#  'alexa',
#  'access',
#  'music',
#  'howard',
#  'stern',
#  'nfl',
#  'mlb',
#  'rest',
#  'satellite',
#  'radio',
#  'content',
#  'thing',
#  'tap',
#  'bluetooth',
#  'speaker',
#  'solo',
#  'alexa',
#  'wifi',
#  'wife',
#  'learning',
#  'process',
#  'benefits',
#  'things',
#  'wife',
#  'commands',
#  'hmmm',
#  'fun',
#  'convenient',
#  'toy',
#  'limitations',
#  'npr',
#  'news',
#  'clip',
#  'news',
#  'news',
#  'news',
#  'highlights',
#  'music',
#  'echo',
#  'songs',
#  'time',
#  'reviews',
#  'amazon',
#  'echo',
#  'products',
#  'portability',
#  'size',
#  'tap',
#  'product',
#  'expectations',
#  'day',
#  'music',
#  'questions',
#  'accent',
#  'problems',
#  'comments',
#  'alexa',
#  'timers/alarms',
#  'lists',
#  'tap',
#  'ability',
#  'room',
#  'room',
#  'patio',
#  'thoughts',
#  'echo',
#  'grow',
#  'list',
#  'tasks',
#  'app',
#  'smartphone',
#  'list',
#  'place',
#  'calls',
#  'echo',
#  'samsung',
#  'smartphone',
#  'disappointed',
#  'fact',
#  'battery',
#  'issues',
#  'rooms',
#  'amount',
#  'bass',
#  'size',
#  'awesome',
#  'speaker',
#  'easy',
#  'easy',
#  'great',
#  'pool',
#  'features',
#  'echo',
#  'house',
#  'w/you',
#  'always',
#  'amazon',
#  'echo',
#  'wherever',
#  'smaller',
#  'sounds',
#  'hands',
#  'button',
#  'penny',
#  'time',
#  'expectations',
#  'product',
#  'friends',
#  'family',
#  'amazon',
#  'tap',
#  'investment',
#  'alexa',
#  'everyday',
#  'love',
#  'someone',
#  'notes',
#  'music',
#  'demand',
#  'bluetooth',
#  'speaker',
#  'alexa',
#  'hands',
#  'things',
#  'quality',
#  'bathroom',
#  'issues',
#  'steam',
#  'echo',
#  'fool',
#  'battery',
#  'everything',
#  'music',
#  'product',
#  'amazon',
#  'account',
#  'part',
#  'conversations',
#  'option',
#  'button',
#  'voice',
#  'command',
#  'way',
#  'till',
#  'google',
#  'device',
#  'devices',
#  'dot',
#  'hate',
#  'tap',
#  'portable',
#  'device',
#  'charge',
#  'day',
#  'dots',
#  'tap',
#  'fun',
#  'music',
#  'relation',
#  'music',
#  'night',
#  'night',
#  'thing',
#  'speaker',
#  'assistance',
#  'alexa',
#  'bluetooth',
#  'speaker',
#  'choice',
#  'needs',
#  'great',
#  'speaker',
#  'sound',
#  'day',
#  'alexa',
#  'network',
#  'amazon',
#  'tap',
#  'complement',
#  'amazon',
#  'echo',
#  'office',
#  'space',
#  'advantages',
#  'echo',
#  'bluetooth',
#  'speaker',
#  'button',
#  'alexa',
#  'issue',
#  'sound',
#  'quality',
#  'bluetooth',
#  'speaker',
#  'market',
#  'alexa',
#  'lots',
#  'things',
#  'fun',
#  'family',
#  'product',
#  'grandkids',
#  'app',
#  'functionality',
#  'compatibility',
#  'speaker',
#  'feature',
#  'friend',
#  'dot',
#  'devices',
#  'echo',
#  'tap',
#  'cnet',
#  'review',
#  'tap',
#  'frustrations',
#  'wake',
#  'word',
#  'alexis',
#  'language',
#  'service',
#  'book',
#  'member',
#  'addition',
#  'household',
#  'guys',
#  'tap',
#  'everything',
#  'echo',
#  'home',
#  'everything',
#  'work',
#  'desk',
#  'music',
#  'weather',
#  'speaker',
#  'great',
#  'sound',
#  'value',
#  'worlds',
#  'bt',
#  'speaker',
#  'amazon',
#  'alexa',
#  'device',
#  'anyone',
#  'bt',
#  'speaker',
#  'alexa',
#  'device',
#  'hours',
#  'day',
#  'wemo-device',
#  'battery',
#  'life',
#  'quality',
#  'voice',
#  'recognition',
#  'tap',
#  'echo',
#  'deck',
#  'tap',
#  'stand',
#  'bothering',
#  'bluetooth',
#  'speakers',
#  'phone',
#  'music',
#  'internet',
#  'tap',
#  'sound',
#  'battery',
#  'wifi',
#  'tooth',
#  'button',
#  'speaker',
#  'fact',
#  'bonus',
#  'alex',
#  'update',
#  'button',
#  'name',
#  'echo',
#  'speaker',
#  'one',
#  'echo',
#  'booming',
#  'sound',
#  'stages',
#  'home',
#  'smartness',
#  'start',
#  'product',
#  'app',
#  'esp',
#  'u.s.',
#  'go',
#  'tooth',
#  'speaker',
#  'touch',
#  'etc',
#  'alexa',
#  'music',
#  'price',
#  'alexa',
#  'addition',
#  ...]

# %%
len(clean_nouns)
# Out:
# 2611898

# %%
df['name'][0].split(" ")
# Out:
# ['Amazon', 'Tap', '-', 'Alexa-Enabled', 'Portable', 'Bluetooth', 'Speaker']

# %%
contextual_stopwords = ['amazon','tap','-','portable','speaker','device']

# %%
final_noun_list = [ noun for noun in clean_nouns if noun not in contextual_stopwords]

# %%
len(final_noun_list)
# Out:
# 2262850

# %%
from collections import Counter

# %%
noun_frequency = Counter(final_noun_list)
noun_frequency
# Out:
# Counter({'important': 542,
#          'update': 5420,
#          'review': 2168,
#          'please': 542,
#          'february': 542,
#          'firmware': 542,
#          'owners': 1084,
#          'option': 7588,
#          'settings': 542,
#          'alexa': 92682,
#          'app': 13008,
#          'respond': 542,
#          'commands': 13008,
#          'echo': 110568,
#          'dot': 21680,
#          'development': 1626,
#          'something': 8130,
#          'thank': 1626,
#          'lack': 1084,
#          'operation': 542,
#          'shortcoming': 542,
#          'lot': 9214,
#          'thing': 10298,
#          'mind': 1084,
#          'battery': 26558,
#          'power': 2710,
#          'mode': 6504,
#          'microphone': 4336,
#          'times': 3252,
#          'life': 11924,
#          'convenience.': 542,
#          'anyway': 542,
#          'days': 3252,
#          'demand': 1626,
#          'risk': 542,
#          'today': 1626,
#          'music': 83468,
#          'listener': 542,
#          'try.i': 1084,
#          'kitchen': 2168,
#          'echos': 2168,
#          'voice': 29810,
#          'control': 5420,
#          'question': 3794,
#          'echo.read': 542,
#          'weeks': 1626,
#          'fact': 5962,
#          'year': 4878,
#          'price': 18428,
#          'remote': 542,
#          'game': 1084,
#          'things': 14092,
#          'devices': 5420,
#          'years': 1626,
#          'home': 20596,
#          'combination': 1084,
#          'smartthings': 542,
#          'ifttt': 542,
#          'logitech': 542,
#          'harmony': 542,
#          'middle': 542,
#          'ability': 5962,
#          'killer': 542,
#          'feature': 8130,
#          'parts': 1084,
#          'echo/tap': 542,
#          'house': 16802,
#          'setup.read': 542,
#          'bluetooth': 34146,
#          'order': 5420,
#          'products': 7588,
#          'services': 4336,
#          'automation': 1084,
#          'more.it': 542,
#          'button': 37398,
#          'dolby': 1084,
#          'stereo': 1626,
#          'speakers': 15718,
#          'version': 4336,
#          'year.ive': 542,
#          'understands': 542,
#          'im': 1084,
#          'time': 26016,
#          'experience': 1084,
#          'well.the': 542,
#          'audio': 1084,
#          'id': 542,
#          'range': 2710,
#          'bose': 2710,
#          'sound': 73170,
#          'bass': 6504,
#          'levels': 1084,
#          'offers': 542,
#          'wi-fi': 1626,
#          'streaming': 2168,
#          'amount': 1626,
#          'value': 3794,
#          'prime': 10840,
#          'music.it': 542,
#          'spotify': 4878,
#          'pandora': 7046,
#          'iheartradio': 1084,
#          'tunein.battery': 542,
#          'ill': 542,
#          'limits': 1084,
#          'life.read': 542,
#          'look': 542,
#          'product': 31978,
#          'replacement': 542,
#          'second': 542,
#          'reason': 2168,
#          'ease': 2168,
#          'recognition': 3252,
#          'notch': 542,
#          'accessories': 542,
#          'problem': 4878,
#          'features': 11924,
#          'money': 2168,
#          'half': 1084,
#          'wemo': 1084,
#          'switch': 542,
#          'lamp': 1084,
#          'ittt': 542,
#          'minutes': 542,
#          'pretty': 1084,
#          'dock': 2710,
#          'cables': 542,
#          'hour': 2168,
#          'day': 10840,
#          'google': 4878,
#          'play': 6504,
#          'imo': 1084,
#          'way': 4336,
#          'apple': 3794,
#          'itunes': 542,
#          'love': 7046,
#          'dollars': 542,
#          'month': 2710,
#          'family': 10298,
#          'plan': 1626,
#          'members': 1084,
#          'access': 7046,
#          'youtube': 542,
#          'phone': 20054,
#          'port': 542,
#          'everything': 12466,
#          'market': 3252,
#          'bit': 3252,
#          'bought': 3252,
#          'deal': 1626,
#          'best': 5962,
#          'buy': 9756,
#          'radio': 7588,
#          'station': 2168,
#          'list': 3794,
#          'set': 542,
#          'timers': 542,
#          'alarms': 542,
#          'nothing': 1626,
#          'hands': 7588,
#          'portability': 20054,
#          'outdoors': 542,
#          'wifi': 13008,
#          'unit': 6504,
#          'cradle': 1626,
#          'news': 9756,
#          'weather': 12466,
#          'items': 3252,
#          'connectivity': 2710,
#          'problems': 2168,
#          'taps': 1084,
#          'fault': 1084,
#          'purchase': 7046,
#          'sounds': 1626,
#          'versions': 542,
#          'versatile': 542,
#          'wireless': 3794,
#          'recharging': 542,
#          'quality': 37398,
#          'phone/tablet': 542,
#          'sale': 5962,
#          'account': 4878,
#          'lights': 3794,
#          'locks': 1084,
#          'surprise': 542,
#          'hardware': 1626,
#          'microphones.sound': 542,
#          'implementation': 542,
#          'space': 1626,
#          'end': 2168,
#          'rates': 542,
#          'everyone': 2168,
#          'share': 1084,
#          'friend': 2168,
#          'great': 28184,
#          'intro': 542,
#          'ai': 1084,
#          'wait': 1084,
#          'reasons': 542,
#          'staff': 542,
#          'gift': 20054,
#          'might': 1626,
#          'lol': 1626,
#          'base': 5962,
#          'room': 14634,
#          'sheer': 542,
#          'outlet': 542,
#          'volume': 8130,
#          'faster': 542,
#          'rate': 542,
#          'stars': 1084,
#          'application': 1084,
#          'command': 6504,
#          'alexas': 1084,
#          'use': 5962,
#          'purchases': 542,
#          'smarter': 542,
#          'trips': 542,
#          'garage': 3794,
#          'never': 542,
#          'issue': 5420,
#          'juice': 542,
#          'mics': 542,
#          'job': 2710,
#          'inna': 542,
#          'package': 542,
#          'concept': 542,
#          'updates': 1626,
#          'item': 9214,
#          'beginning': 542,
#          'request': 1626,
#          'inventions': 542,
#          'songs': 4878,
#          'addition': 7588,
#          'smarthome': 542,
#          'system': 4878,
#          'ac': 542,
#          'annoyance': 542,
#          'wake': 3252,
#          'word': 3252,
#          'fort': 542,
#          'son': 4336,
#          'user': 542,
#          'information': 5962,
#          'highway': 542,
#          'father': 1626,
#          'favorite': 1084,
#          'kids': 7588,
#          'dj': 542,
#          'unlimited': 542,
#          'program': 542,
#          'purposes': 542,
#          'audiophiles': 542,
#          'software': 2710,
#          'machine': 1084,
#          'issues': 4336,
#          'reviews': 3252,
#          'purchasing': 542,
#          'one': 5962,
#          'brother': 2168,
#          'fave': 542,
#          'tunes': 1084,
#          'pool': 3794,
#          'charge': 9214,
#          'hours': 2710,
#          'listening': 1084,
#          'anything': 4336,
#          'deck': 3252,
#          'cup': 542,
#          'coffee': 542,
#          'husband': 1626,
#          'mom': 2168,
#          'draugther': 542,
#          'self': 542,
#          'ganes': 542,
#          'household': 1626,
#          'size': 12466,
#          'choice': 2168,
#          'hotspot': 2168,
#          'data': 542,
#          'go': 5420,
#          'rooms': 1084,
#          'patio': 2710,
#          'perfect': 3794,
#          'siriusxm': 542,
#          'howard': 542,
#          'stern': 542,
#          'nfl': 542,
#          'mlb': 542,
#          'rest': 1084,
#          'satellite': 542,
#          'content': 1626,
#          'solo': 542,
#          'wife': 5420,
#          'learning': 542,
#          'process': 542,
#          'benefits': 1626,
#          'hmmm': 542,
#          'fun': 14092,
#          'convenient': 1084,
#          'toy': 1084,
#          'limitations': 542,
#          'npr': 542,
#          'clip': 542,
#          'highlights': 542,
#          'expectations': 1084,
#          'questions': 11924,
#          'accent': 1084,
#          'comments': 542,
#          'timers/alarms': 542,
#          'lists': 3252,
#          'thoughts': 542,
#          'grow': 542,
#          'tasks': 542,
#          'smartphone': 1626,
#          'place': 1626,
#          'calls': 542,
#          'samsung': 542,
#          'disappointed': 542,
#          'awesome': 3252,
#          'easy': 6504,
#          'w/you': 542,
#          'always': 2168,
#          'wherever': 542,
#          'smaller': 1084,
#          'penny': 1626,
#          'friends': 3252,
#          'investment': 1084,
#          'everyday': 542,
#          'someone': 2710,
#          'notes': 542,
#          'bathroom': 542,
#          'steam': 542,
#          'fool': 1626,
#          'part': 3252,
#          'conversations': 1084,
#          'till': 542,
#          'hate': 542,
#          'dots': 3794,
#          'relation': 542,
#          'night': 1084,
#          'assistance': 542,
#          'needs': 2710,
#          'network': 2168,
#          'complement': 1084,
#          'office': 4336,
#          'advantages': 542,
#          'lots': 2168,
#          'grandkids': 542,
#          'functionality': 2710,
#          'compatibility': 542,
#          'cnet': 542,
#          'frustrations': 542,
#          'alexis': 1084,
#          'language': 542,
#          'service': 3252,
#          'book': 1084,
#          'member': 2710,
#          'guys': 542,
#          'work': 6504,
#          'desk': 542,
#          'worlds': 542,
#          'bt': 1626,
#          'anyone': 3794,
#          'wemo-device': 542,
#          'stand': 3794,
#          'bothering': 542,
#          'internet': 2168,
#          'tooth': 3794,
#          'bonus': 2168,
#          'alex': 542,
#          'name': 4336,
#          'booming': 542,
#          'stages': 542,
#          'smartness': 542,
#          'start': 542,
#          'esp': 542,
#          'u.s.': 542,
#          'touch': 2168,
#          'etc': 1626,
#          'commercial': 542,
#          'capabilities': 4336,
#          'anywhere': 542,
#          'projects': 542,
#          'shopping': 1084,
#          'games': 1084,
#          'pack': 542,
#          'plug': 1084,
#          'cord': 2168,
#          'activation': 4336,
#          'travel': 2168,
#          'makes': 542,
#          'alarm': 4336,
#          'reminder': 542,
#          'benefit': 542,
#          'advertise': 542,
#          'bedroom': 2168,
#          'crisp': 542,
#          'satchel': 542,
#          'yard': 2168,
#          'gathering': 1084,
#          'seconds': 542,
#          'player': 1084,
#          'tons': 1084,
#          'advantage': 1084,
#          'alezxa': 542,
#          'search': 1626,
#          'algorithms': 542,
#          'stuff': 542,
#          'described': 542,
#          'buys': 542,
#          'better': 542,
#          'upgrade': 542,
#          '....': 542,
#          'timer': 2710,
#          'light': 1084,
#          'controls': 542,
#          'basis': 2168,
#          'smart': 1084,
#          'earth': 542,
#          'car': 1084,
#          'sync': 1084,
#          'aps': 542,
#          'clock-': 542,
#          'books': 1084,
#          'rides': 542,
#          'business': 542,
#          'ecobee': 542,
#          'off/on': 542,
#          'commandscons': 542,
#          'band': 542,
#          'par': 1084,
#          'usefulness': 542,
#          'cons': 1084,
#          'companion.tip': 542,
#          'bestbuy': 1084,
#          'cases': 542,
#          'protector': 542,
#          'flexibility': 542,
#          'ages': 542,
#          'xmas': 542,
#          'fast': 1084,
#          'mother': 2168,
#          'making': 542,
#          'hand': 2710,
#          'current': 542,
#          'planning': 542,
#          'details': 1084,
#          'sits': 542,
#          'bed': 1626,
#          'ijnfo': 542,
#          'calendar': 2168,
#          'plans': 542,
#          'store': 1626,
#          'guess': 1084,
#          'phillips': 1084,
#          'hue': 1084,
#          'starter': 542,
#          'kit': 542,
#          'honeywell': 542,
#          'thermostat': 1626,
#          'birthday.she': 542,
#          'need': 2710,
#          'apps': 2710,
#          'lighting': 542,
#          'temperature': 542,
#          'requests': 4336,
#          'nice': 3794,
#          'christmas': 7046,
#          'course': 1084,
#          'integration': 1084,
#          'source': 1626,
#          'medium': 542,
#          'stations': 2168,
#          'clock': 1626,
#          'sets': 542,
#          'pause': 542,
#          'charger': 1084,
#          'annoying': 1084,
#          'thumbs': 542,
#          'substitute': 542,
#          'tip': 1084,
#          'iceberg': 542,
#          'conpack': 542,
#          'works': 5962,
#          'fluke': 542,
#          'refund': 542,
#          'must': 1626,
#          'step': 1626,
#          'brain': 542,
#          'potential': 542,
#          'extension': 1084,
#          'options': 542,
#          '..': 9214,
#          'person': 1084,
#          'glass': 542,
#          'default': 542,
#          'feb': 542,
#          'expense': 542,
#          'grille': 542,
#          'pictures': 542,
#          'fabric': 1626,
#          'grilles': 542,
#          'micrphones': 542,
#          'firm': 542,
#          'sling': 1626,
#          'case': 3794,
#          'charging': 1084,
#          'kind': 2168,
#          'case.-': 542,
#          'micro': 542,
#          'usb': 1084,
#          'cable': 1084,
#          'back': 542,
#          'hi': 542,
#          'week': 1626,
#          'facts': 542,
#          'events': 1626,
#          'assistant': 2710,
#          'assists': 542,
#          'loud': 2168,
#          'outside': 1084,
#          'law': 1084,
#          'gardening': 542,
#          'huuuge': 542,
#          'batteries': 542,
#          'setup': 1626,
#          'fot': 542,
#          'daughter': 5962,
#          'downside': 2710,
#          'couple': 2168,
#          'hit': 542,
#          'morning': 542,
#          'guests': 542,
#          'links': 1084,
#          'usage': 2168,
#          'instructio': 542,
#          'tv': 542,
#          'close': 542,
#          'pits': 542,
#          'sometimes': 542,
#          'tries': 1084,
#          'talk': 542,
#          'model': 1626,
#          'punch': 542,
#          'form': 1626,
#          'info': 1084,
#          'interface': 2710,
#          'cell': 1626,
#          'computer': 2710,
#          'engine': 1084,
#          'got': 1084,
#          'sleep': 542,
#          'design': 1084,
#          'ideal': 542,
#          'keeps': 1626,
#          'question.': 542,
#          'surprised': 542,
#          'ask': 542,
#          'enjoy': 1084,
#          'supplies': 542,
#          '.....': 1626,
#          'collection': 542,
#          'girlfriend': 1626,
#          'opinion': 542,
#          'skills': 2168,
#          'yes': 542,
#          'charts': 1084,
#          'movies': 2168,
#          'camping': 1084,
#          'trip': 1084,
#          'cool': 2168,
#          'season': 542,
#          'done': 542,
#          'iphone': 1084,
#          'arm': 542,
#          'reach': 1084,
#          'caveats': 542,
#          'convenience': 1084,
#          'idea': 1084,
#          'small': 1626,
#          'serves': 542,
#          'technology': 4336,
#          'luck': 542,
#          'world': 1626,
#          'gifts': 1626,
#          'flash': 1084,
#          'joke': 1084,
#          'tool': 1084,
#          'renders': 542,
#          'kinks': 542,
#          'birthday': 542,
#          'inputs': 542,
#          'example': 1084,
#          'yesterday': 542,
#          'mariachi': 542,
#          'odd': 542,
#          'conversation': 542,
#          'bill': 1084,
#          'ca': 542,
#          'summer': 542,
#          'holidays': 542,
#          'black': 1084,
#          'friday': 1626,
#          'maybe': 542,
#          'blutooth': 542,
#          'eavsdropping': 542,
#          'months': 1626,
#          'connection': 3252,
#          'star': 1626,
#          'beach': 2168,
#          'lake': 1084,
#          'park': 542,
#          'arms': 542,
#          'activate': 542,
#          'traffic': 1084,
#          'sports': 1626,
#          'scores/schedules': 542,
#          'improvements': 542,
#          'helper': 1084,
#          'jbl': 1626,
#          'ton': 542,
#          'plain': 542,
#          'simple': 1084,
#          'ones': 542,
#          'buttons': 542,
#          'top': 542,
#          'front': 542,
#          'blue': 542,
#          'daughter.she': 542,
#          'electronics': 542,
#          'alley': 542,
#          'girl': 1084,
#          'haha': 542,
#          'th': 1084,
#          'present': 1084,
#          'clarity': 542,
#          'alexia': 542,
#          'responses': 542,
#          'factor': 1084,
#          'others': 2710,
#          'worth': 1084,
#          'usd150.00': 542,
#          'outdoor': 1084,
#          'chance': 1084,
#          'catch': 542,
#          'purpose': 1084,
#          'compare': 542,
#          'ue': 1084,
#          'boom.the': 542,
#          'promotion': 542,
#          'cost': 1084,
#          'pain': 542,
#          'sometimes.if': 542,
#          'husbands': 542,
#          'desktop': 542,
#          'nephew': 1626,
#          'fire': 1084,
#          'stick': 542,
#          'meantime': 542,
#          'gadgets': 542,
#          'took': 1084,
#          'awhile': 542,
#          'lags': 542,
#          'circlers': 542,
#          'lives': 1084,
#          'dystopia': 542,
#          'david': 542,
#          'eggers': 542,
#          'circle': 542,
#          'prompts': 542,
#          'video': 542,
#          'pizza': 542,
#          'uber': 542,
#          'people': 2168,
#          'granddaughters': 542,
#          'pf': 542,
#          'plugs': 1084,
#          'basement': 1084,
#          'area': 1084,
#          'overall': 542,
#          'selections': 542,
#          'belkin': 542,
#          'gave': 542,
#          'gift.did': 542,
#          'anytime': 542,
#          'camera': 542,
#          'yearbook': 542,
#          'school': 542,
#          'answers': 542,
#          'highly': 542,
#          'link': 1084,
#          'directions': 542,
#          'u': 542,
#          'mobility': 1084,
#          'fan': 1626,
#          'configuration': 542,
#          'answer': 2168,
#          'nursing': 542,
#          'ultimate': 542,
#          'whole': 1084,
#          'cult': 542,
#          'flaw': 1084,
#          'triby': 542,
#          'note': 542,
#          'switches/remembers': 542,
#          'areas': 542,
#          'hot': 542,
#          'spot': 1084,
#          'enhancements': 542,
#          'partnerships': 542,
#          'siri': 3252,
#          'waterproof': 1084,
#          'eco-system': 542,
#          'produces': 542,
#          'plays': 1626,
#          'cloud': 1626,
#          'accounts': 542,
#          'wall': 542,
#          'functions': 2168,
#          'concert': 542,
#          'hall': 542,
#          'hrs': 542,
#          'currently': 542,
#          'syncs': 542,
#          'building': 542,
#          'cloth': 542,
#          'dirty': 1084,
#          'og': 542,
#          'water': 1084,
#          'proof': 542,
#          'audiophile': 1084,
#          'except': 542,
#          'level': 1084,
#          'connect': 542,
#          'gizmo': 542,
#          'halloween': 542,
#          'party': 542,
#          'clocks': 542,
#          'podcasts': 1084,
#          'domino': 542,
#          'degree': 542,
#          'membership': 542,
#          'scores': 1084,
#          'lets': 542,
#          'type': 542,
#          'hotel': 542,
#          "wifi'sseems": 542,
#          'reports': 1084,
#          'adjusts': 542,
#          'status': 542,
#          'good': 1084,
#          'footprint': 542,
#          'almost': 542,
#          'version.great': 542,
#          'distortion': 542,
#          'alternatives': 542,
#          'whim': 542,
#          "'smart": 542,
#          'marketing': 542,
#          'tag': 542,
#          'trick': 542,
#          'distance': 542,
#          'aspect': 1084,
#          'reminders': 542,
#          'replaces': 542,
#          'cds': 542,
#          'backpack': 542,
#          'speaking': 542,
#          'guam': 542,
#          'online': 1084,
#          'instructions': 1626,
#          'boyfriend': 542,
#          'receiver': 542,
#          'covenient': 542,
#          'point': 1084,
#          'quicker': 542,
#          'google.com': 542,
#          'mini': 1626,
#          'beats': 1084,
#          'competitors': 542,
#          'playlists': 542,
#          'song': 1084,
#          'library': 1084,
#          'forecasts': 542,
#          'switches': 542,
#          'knowledge': 1084,
#          'plus': 1084,
#          'full': 542,
#          'disclosure': 542,
#          'echoes': 1084,
#          'honestly': 542,
#          'amazons': 542,
#          'fit': 542,
#          'runs': 542,
#          'sense': 542,
#          'someways': 542,
#          'table': 1084,
#          'wars': 542,
#          'blown': 1084,
#          'michael': 542,
#          'bolton': 542,
#          'bruce': 542,
#          'springsteen': 542,
#          'bottom': 542,
#          'line': 542,
#          'highs': 1084,
#          'lows': 1626,
#          'piece': 1084,
#          'crystal': 542,
#          'majority': 542,
#          'date': 1084,
#          'artist': 542,
#          'iffy': 542,
#          'company': 542,
#          'session': 542,
#          'xm': 1084,
#          'help': 1084,
#          'woman': 542,
#          'novelty': 542,
#          'excellent': 542,
#          'capabilities-': 542,
#          'get': 542,
#          'pre': 542,
#          'premium': 542,
#          'ipod': 542,
#          'entertaining': 542,
#          'brought': 542,
#          'sister': 542,
#          'laptop': 542,
#          'brainer': 542,
#          'apartment': 542,
#          'research': 1084,
#          'privacy': 542,
#          'speech': 542,
#          'surroundings': 542,
#          'worries': 542,
#          'macbook': 542,
#          'likenit': 542,
#          'portablebility': 542,
#          'style': 542,
#          'lithium': 542,
#          'leader': 542,
#          'aws': 542,
#          'opportunity': 542,
#          'community': 542,
#          'interaction': 542,
#          'environment': 542,
#          'innovation': 542,
#          'try': 542,
#          'guy': 1626,
#          'remembers': 542,
#          'connections': 542,
#          'side': 1084,
#          'in.the': 542,
#          'category': 542,
#          'none': 542,
#          'package.i': 542,
#          'movie': 542,
#          'cute': 542,
#          'soundlink': 1084,
#          'prime/alexa': 542,
#          'omg': 542,
#          'wires': 542,
#          'deals': 542,
#          'drive': 542,
#          'closet': 542,
#          'grab': 542,
#          'format': 542,
#          'ft.': 542,
#          'tx': 542,
#          'mimi': 542,
#          'grandmother': 542,
#          'dancing': 542,
#          'amazon.com': 542,
#          'cylinder': 1084,
#          'kdis': 542,
#          'interruptions': 542,
#          'commercials': 542,
#          'long': 542,
#          'difference': 1626,
#          'networks': 542,
#          'tends': 542,
#          'coll': 542,
#          'gadget': 1626,
#          'reception': 542,
#          'iheart': 542,
#          'namesake': 542,
#          'charges': 542,
#          'rocks': 542,
#          'stutters': 542,
#          'stays': 542,
#          'feel': 542,
#          'cover': 1084,
#          'upholstery': 542,
#          'plastic': 542,
#          'future': 1084,
#          'remotes': 542,
#          'wi': 1084,
#          'fi': 1084,
#          'audible': 542,
#          'ebooks': 542,
#          'btw': 542,
#          'texas': 542,
#          'entertainment': 542,
#          'wireless.it': 1084,
#          'handsâ€¦you': 542,
#          'grandchildren': 542,
#          'road': 542,
#          'expenses': 542,
#          'amazement': 542,
#          'material': 542,
#          'size.the': 542,
#          'disadvantage': 542,
#          'call': 542,
#          'function': 2168,
#          'change': 542,
#          'pace': 542,
#          'avarage': 542,
#          'genre': 542,
#          'huge': 542,
#          'generation': 542,
#          'want': 542,
#          'flawless': 542,
#          'tuning': 542,
#          'mention': 542,
#          'beef': 542,
#          'paired': 542,
#          'these-': 542,
#          'bluetooth/wifi': 542,
#          'b': 542,
#          'c.': 542,
#          'seamless': 542,
#          'savvy': 542,
#          'rating': 542,
#          'repository': 542,
#          'playback': 1084,
#          'glitches': 542,
#          'tunein': 1084,
#          'channels.it': 542,
#          'kid': 1626,
#          'beat': 1084,
#          'box': 1626,
#          'hvac': 542,
#          'random': 542,
#          'snap': 542,
#          'okay': 542,
#          'adoptor': 542,
#          'phones': 542,
#          'forte': 542,
#          'drop': 542,
#          'def': 542,
#          'sweden': 542,
#          'portugal': 542,
#          'houses': 1084,
#          'host': 542,
#          'card': 542,
#          'new': 542,
#          'response': 1084,
#          'resistant': 542,
#          'tub': 1084,
#          'episode': 542,
#          'spectacular': 542,
#          'steals': 542,
#          'thunder': 542,
#          'went': 542,
#          'chagrin': 542,
#          'granddaughter': 1084,
#          'sounding': 542,
#          'freedom': 542,
#          'knock': 1084,
#          'jokes': 542,
#          'crack': 542,
#          'anybody': 542,
#          'informs': 542,
#          'forcast': 542,
#          'capability': 1084,
#          'college': 1084,
#          'students': 542,
#          'solution': 542,
#          'companion': 542,
#          'stream': 1084,
#          'housework': 542,
#          'situation': 542,
#          'tablet': 542,
#          'bumper': 542,
#          'adult': 542,
#          'describe': 542,
#          'kick': 542,
#          'trial': 542,
#          'error': 542,
#          'roll': 542,
#          'announcement': 542,
#          'dan': 542,
#          'marino': 542,
#          'briefs': 542,
#          'shower': 542,
#          'extra': 542,
#          'push': 1084,
#          'really': 542,
#          ...})

# %%
most_common =noun_frequency.most_common(20)
most_common
# Out:
# [('echo', 110568),
#  ('alexa', 92682),
#  ('music', 83468),
#  ('sound', 73170),
#  ('button', 37398),
#  ('quality', 37398),
#  ('bluetooth', 34146),
#  ('product', 31978),
#  ('voice', 29810),
#  ('great', 28184),
#  ('battery', 26558),
#  ('time', 26016),
#  ('dot', 21680),
#  ('home', 20596),
#  ('phone', 20054),
#  ('portability', 20054),
#  ('gift', 20054),
#  ('price', 18428),
#  ('house', 16802),
#  ('speakers', 15718)]

# %%
[word for word, frequency in most_common]
# Out:
# ['echo',
#  'alexa',
#  'music',
#  'sound',
#  'button',
#  'quality',
#  'bluetooth',
#  'product',
#  'voice',
#  'great',
#  'battery',
#  'time',
#  'dot',
#  'home',
#  'phone',
#  'portability',
#  'gift',
#  'price',
#  'house',
#  'speakers']
