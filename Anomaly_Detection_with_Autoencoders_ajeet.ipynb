# %% [markdown]
# <a href="https://colab.research.google.com/github/ajeetranaut/Assignment/blob/master/Anomaly_Detection_with_Autoencoders_ajeet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras

# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 10,8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %%
tf.__version__
# Out:
# '2.8.2'

# %%
keras.__version__
# Out:
# '2.8.0'

# %%
#loading Data
path='/content/creditcard.csv'
df = pd.read_csv(path)

# %%
#shape of data
df.shape
# Out:
# (3973, 31)

# %%
#checking missing value
df.isnull().values.any()
# Out:
# True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3973 entries, 0 to 3972
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    3973 non-null   int64
#  1   V1      3973 non-null   float64
#  2   V2      3973 non-null   float64
#  3   V3      3973 non-null   float64
#  4   V4      3973 non-null   float64
#  5   V5      3973 non-null   float64
#  6   V6      3973 non-null   float64
#  7   V7      3973 non-null   float64
#  8   V8      3973 non-null   float64
#  9   V9      3973 non-null   float64
#  10  V10     3973 non-null   float64
#  11  V11     3973 non-null   float64
#  12  V12     3973 non-null   float64
#  13  V13     3973 non-null   float64
#  14  V14     3973 non-null   float64
#  15  V15     3973 non-null   float64
#  16  V16     3973 non-null   float64
#  17  V17     3973 non-null   float64
#  18  V18     3973 non-null   float64
#  19  V19     3973 non-null   float64
#  20  V20     3973 non-null   float64
#  21  V21     3973 non-null   float64
#  22  V22     3973 non-null   float64
#  23  V23     3972 non-null   float64
#  24  V24     3972 non-null   float64
#  25  V25     3972 non-null   float64
#  26  V26     3972 non-null   float64
#  27  V27     3972 non-null   float64
#  28  V28     3972 non-null   float64
#  29  Amount  3972 non-null   float64
#  30  Class   3972 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 962.3 KB

# %%
df
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0        0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2        1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3        1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4        2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...    ...       ...       ...       ...       ...       ...       ...
# 3968  3617  1.134592  0.252051  0.488592  0.799826 -0.264819 -0.369918
# 3969  3621 -1.338671  1.080974  1.291196  0.719258  0.101320  0.053896
# 3970  3622 -0.339728 -2.417449  0.975517  2.537995 -1.720361  0.863005
# 3971  3623 -0.368639  0.947432  1.707755  0.932092  0.292956  0.189100
# 3972  3624 -0.663445  1.162921  1.508050  0.549405  0.231377 -0.106041
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 0     0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1    -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2     0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3     0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4     0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...        ...       ...       ...  ...       ...       ...       ...
# 3968 -0.243365  0.049761  1.210818  ... -0.351115 -0.851463  0.186169
# 3969  0.001297 -0.917575  1.638510  ...  0.498030 -0.483932  0.037686
# 3970  0.032965  0.026764  2.487139  ...  0.391639  0.264432 -0.735031
# 3971  0.499330  0.132466  0.779412  ... -0.119045  0.056665 -0.172703
# 3972  0.817977 -0.387026  1.488054  ... -0.420337 -0.361357       NaN
#
#            V24       V25       V26       V27       V28  Amount  Class
# 0     0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1    -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2    -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3    -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4     0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...        ...       ...       ...       ...       ...     ...    ...
# 3968  0.092463  0.020015  0.057976 -0.046611  0.012562   13.99    0.0
# 3969  0.053566 -0.560078  0.230423 -0.119911  0.321847   27.43    0.0
# 3970  0.450594  0.310022 -0.231357 -0.049872  0.153526  730.32    0.0
# 3971  0.170073  0.139605 -0.420518  0.033794  0.005996    6.87    0.0
# 3972       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [3973 rows x 31 columns]

# %%
#df = df.rolling(window=5).mean()

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

# %%
frauds.shape
# Out:
# (2, 31)

# %%
normal.shape
# Out:
# (3970, 31)

# %%
frauds.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    3970.000000
# mean       64.899597
# std       213.612570
# min         0.000000
# 25%         2.270000
# 50%        12.990000
# 75%        54.990000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.Amount, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.Amount, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 20000))
plt.yscale('log')
plt.show();

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %% [markdown]
# Preparing the data

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
#Training Autoencoder

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (3175, 29)

# %% [markdown]
# ###Building the model
# Our Autoencoder uses 4 fully connected layers with 14, 7, 7 and 29 neurons respectively. The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 14

# %%
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 2), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 2), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)

autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# Let's train our model for 100 epochs with a batch size of 32 samples and save the best performing model to a file. The ModelCheckpoint provided by Keras is really handy for such tasks. Additionally, the training progress will be exported in a format that TensorBoard understands.

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
# 100/100 [==============================] - 1s 4ms/step - loss: 0.8493 - accuracy: 0.1676 - val_loss: 0.7386 - val_accuracy: 0.2805
# Epoch 2/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.8023 - accuracy: 0.2614 - val_loss: 0.7017 - val_accuracy: 0.3132
# Epoch 3/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7664 - accuracy: 0.3443 - val_loss: 0.6722 - val_accuracy: 0.4201
# Epoch 4/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.7393 - accuracy: 0.4054 - val_loss: 0.6524 - val_accuracy: 0.4252
# Epoch 5/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.7193 - accuracy: 0.4211 - val_loss: 0.6335 - val_accuracy: 0.4352
# Epoch 6/100
# 100/100 [==============================] - 0s 4ms/step - loss: 0.7024 - accuracy: 0.4372 - val_loss: 0.6183 - val_accuracy: 0.4541
# Epoch 7/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6881 - accuracy: 0.4643 - val_loss: 0.6067 - val_accuracy: 0.4692
# Epoch 8/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6782 - accuracy: 0.4800 - val_loss: 0.5996 - val_accuracy: 0.4868
# Epoch 9/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6715 - accuracy: 0.4986 - val_loss: 0.5948 - val_accuracy: 0.5145
# Epoch 10/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6663 - accuracy: 0.5143 - val_loss: 0.5900 - val_accuracy: 0.5195
# Epoch 11/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6614 - accuracy: 0.5194 - val_loss: 0.5861 - val_accuracy: 0.5409
# Epoch 12/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6576 - accuracy: 0.5282 - val_loss: 0.5828 - val_accuracy: 0.5497
# Epoch 13/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6539 - accuracy: 0.5361 - val_loss: 0.5794 - val_accuracy: 0.5472
# Epoch 14/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6504 - accuracy: 0.5370 - val_loss: 0.5763 - val_accuracy: 0.5572
# Epoch 15/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6471 - accuracy: 0.5427 - val_loss: 0.5730 - val_accuracy: 0.5623
# Epoch 16/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.5474 - val_loss: 0.5700 - val_accuracy: 0.5686
# Epoch 17/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6402 - accuracy: 0.5572 - val_loss: 0.5671 - val_accuracy: 0.5711
# Epoch 18/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6370 - accuracy: 0.5635 - val_loss: 0.5640 - val_accuracy: 0.5799
# Epoch 19/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6333 - accuracy: 0.5776 - val_loss: 0.5600 - val_accuracy: 0.5899
# Epoch 20/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6288 - accuracy: 0.5836 - val_loss: 0.5559 - val_accuracy: 0.6025
# Epoch 21/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6248 - accuracy: 0.6003 - val_loss: 0.5523 - val_accuracy: 0.6189
# Epoch 22/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6211 - accuracy: 0.6088 - val_loss: 0.5489 - val_accuracy: 0.6239
# Epoch 23/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6177 - accuracy: 0.6173 - val_loss: 0.5461 - val_accuracy: 0.6340
# Epoch 24/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6149 - accuracy: 0.6243 - val_loss: 0.5437 - val_accuracy: 0.6327
# Epoch 25/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6122 - accuracy: 0.6243 - val_loss: 0.5417 - val_accuracy: 0.6440
# Epoch 26/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6098 - accuracy: 0.6265 - val_loss: 0.5396 - val_accuracy: 0.6491
# Epoch 27/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6076 - accuracy: 0.6334 - val_loss: 0.5381 - val_accuracy: 0.6503
# Epoch 28/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6058 - accuracy: 0.6353 - val_loss: 0.5362 - val_accuracy: 0.6642
# Epoch 29/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6040 - accuracy: 0.6365 - val_loss: 0.5350 - val_accuracy: 0.6516
# Epoch 30/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6021 - accuracy: 0.6419 - val_loss: 0.5334 - val_accuracy: 0.6642
# Epoch 31/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6004 - accuracy: 0.6444 - val_loss: 0.5318 - val_accuracy: 0.6692
# Epoch 32/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5987 - accuracy: 0.6469 - val_loss: 0.5309 - val_accuracy: 0.6667
# Epoch 33/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5972 - accuracy: 0.6444 - val_loss: 0.5297 - val_accuracy: 0.6692
# Epoch 34/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5958 - accuracy: 0.6482 - val_loss: 0.5291 - val_accuracy: 0.6604
# Epoch 35/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5944 - accuracy: 0.6529 - val_loss: 0.5277 - val_accuracy: 0.6654
# Epoch 36/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.6576 - val_loss: 0.5270 - val_accuracy: 0.6730
# Epoch 37/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.6507 - val_loss: 0.5264 - val_accuracy: 0.6881
# Epoch 38/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5910 - accuracy: 0.6595 - val_loss: 0.5259 - val_accuracy: 0.6742
# Epoch 39/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.6491 - val_loss: 0.5248 - val_accuracy: 0.6805
# Epoch 40/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5886 - accuracy: 0.6545 - val_loss: 0.5238 - val_accuracy: 0.6755
# Epoch 41/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5877 - accuracy: 0.6491 - val_loss: 0.5234 - val_accuracy: 0.6843
# Epoch 42/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5864 - accuracy: 0.6517 - val_loss: 0.5224 - val_accuracy: 0.6805
# Epoch 43/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5854 - accuracy: 0.6542 - val_loss: 0.5217 - val_accuracy: 0.6830
# Epoch 44/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5842 - accuracy: 0.6608 - val_loss: 0.5208 - val_accuracy: 0.6843
# Epoch 45/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5833 - accuracy: 0.6598 - val_loss: 0.5201 - val_accuracy: 0.6868
# Epoch 46/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5824 - accuracy: 0.6620 - val_loss: 0.5196 - val_accuracy: 0.6906
# Epoch 47/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5817 - accuracy: 0.6643 - val_loss: 0.5195 - val_accuracy: 0.6906
# Epoch 48/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5809 - accuracy: 0.6652 - val_loss: 0.5185 - val_accuracy: 0.6931
# Epoch 49/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5801 - accuracy: 0.6617 - val_loss: 0.5181 - val_accuracy: 0.6918
# Epoch 50/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5793 - accuracy: 0.6614 - val_loss: 0.5179 - val_accuracy: 0.6943
# Epoch 51/100
# 100/100 [==============================] - 1s 9ms/step - loss: 0.5786 - accuracy: 0.6696 - val_loss: 0.5183 - val_accuracy: 0.6994
# Epoch 52/100
# 100/100 [==============================] - 0s 5ms/step - loss: 0.5780 - accuracy: 0.6671 - val_loss: 0.5173 - val_accuracy: 0.6943
# Epoch 53/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5773 - accuracy: 0.6709 - val_loss: 0.5170 - val_accuracy: 0.6855
# Epoch 54/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.6709 - val_loss: 0.5164 - val_accuracy: 0.7006
# Epoch 55/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5759 - accuracy: 0.6721 - val_loss: 0.5157 - val_accuracy: 0.6969
# Epoch 56/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5752 - accuracy: 0.6762 - val_loss: 0.5153 - val_accuracy: 0.6981
# Epoch 57/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5747 - accuracy: 0.6756 - val_loss: 0.5153 - val_accuracy: 0.6943
# Epoch 58/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5740 - accuracy: 0.6724 - val_loss: 0.5149 - val_accuracy: 0.6918
# Epoch 59/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5737 - accuracy: 0.6806 - val_loss: 0.5147 - val_accuracy: 0.6918
# Epoch 60/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5729 - accuracy: 0.6753 - val_loss: 0.5142 - val_accuracy: 0.6943
# Epoch 61/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5725 - accuracy: 0.6769 - val_loss: 0.5138 - val_accuracy: 0.6931
# Epoch 62/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5717 - accuracy: 0.6721 - val_loss: 0.5135 - val_accuracy: 0.6881
# Epoch 63/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.6787 - val_loss: 0.5133 - val_accuracy: 0.7057
# Epoch 64/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5706 - accuracy: 0.6784 - val_loss: 0.5131 - val_accuracy: 0.6931
# Epoch 65/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5702 - accuracy: 0.6784 - val_loss: 0.5131 - val_accuracy: 0.7044
# Epoch 66/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5698 - accuracy: 0.6813 - val_loss: 0.5126 - val_accuracy: 0.7044
# Epoch 67/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5691 - accuracy: 0.6831 - val_loss: 0.5128 - val_accuracy: 0.7006
# Epoch 68/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5688 - accuracy: 0.6828 - val_loss: 0.5125 - val_accuracy: 0.7019
# Epoch 69/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5682 - accuracy: 0.6784 - val_loss: 0.5118 - val_accuracy: 0.6943
# Epoch 70/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5674 - accuracy: 0.6831 - val_loss: 0.5120 - val_accuracy: 0.6943
# Epoch 71/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5672 - accuracy: 0.6775 - val_loss: 0.5118 - val_accuracy: 0.6881
# Epoch 72/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5667 - accuracy: 0.6831 - val_loss: 0.5111 - val_accuracy: 0.7006
# Epoch 73/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5664 - accuracy: 0.6863 - val_loss: 0.5106 - val_accuracy: 0.7019
# Epoch 74/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5658 - accuracy: 0.6800 - val_loss: 0.5109 - val_accuracy: 0.6943
# Epoch 75/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5656 - accuracy: 0.6869 - val_loss: 0.5107 - val_accuracy: 0.7019
# Epoch 76/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5650 - accuracy: 0.6806 - val_loss: 0.5108 - val_accuracy: 0.6943
# Epoch 77/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5645 - accuracy: 0.6869 - val_loss: 0.5097 - val_accuracy: 0.6969
# Epoch 78/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5642 - accuracy: 0.6813 - val_loss: 0.5104 - val_accuracy: 0.6994
# Epoch 79/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5643 - accuracy: 0.6860 - val_loss: 0.5099 - val_accuracy: 0.7057
# Epoch 80/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5635 - accuracy: 0.6866 - val_loss: 0.5100 - val_accuracy: 0.7094
# Epoch 81/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5635 - accuracy: 0.6797 - val_loss: 0.5097 - val_accuracy: 0.7082
# Epoch 82/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5625 - accuracy: 0.6872 - val_loss: 0.5097 - val_accuracy: 0.7019
# Epoch 83/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5621 - accuracy: 0.6847 - val_loss: 0.5098 - val_accuracy: 0.6981
# Epoch 84/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5617 - accuracy: 0.6869 - val_loss: 0.5098 - val_accuracy: 0.7082
# Epoch 85/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5613 - accuracy: 0.6860 - val_loss: 0.5089 - val_accuracy: 0.7006
# Epoch 86/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5610 - accuracy: 0.6872 - val_loss: 0.5098 - val_accuracy: 0.6981
# Epoch 87/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5609 - accuracy: 0.6910 - val_loss: 0.5090 - val_accuracy: 0.6969
# Epoch 88/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5603 - accuracy: 0.6866 - val_loss: 0.5083 - val_accuracy: 0.7094
# Epoch 89/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5599 - accuracy: 0.6888 - val_loss: 0.5091 - val_accuracy: 0.7057
# Epoch 90/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5598 - accuracy: 0.6822 - val_loss: 0.5086 - val_accuracy: 0.7057
# Epoch 91/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5592 - accuracy: 0.6917 - val_loss: 0.5081 - val_accuracy: 0.7019
# Epoch 92/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5589 - accuracy: 0.6898 - val_loss: 0.5083 - val_accuracy: 0.7057
# Epoch 93/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5590 - accuracy: 0.6913 - val_loss: 0.5083 - val_accuracy: 0.7069
# Epoch 94/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5584 - accuracy: 0.6850 - val_loss: 0.5090 - val_accuracy: 0.7145
# Epoch 95/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5583 - accuracy: 0.6882 - val_loss: 0.5083 - val_accuracy: 0.6994
# Epoch 96/100
# 100/100 [==============================] - 0s 2ms/step - loss: 0.5580 - accuracy: 0.6885 - val_loss: 0.5087 - val_accuracy: 0.7107
# Epoch 97/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.6891 - val_loss: 0.5077 - val_accuracy: 0.7119
# Epoch 98/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5580 - accuracy: 0.6835 - val_loss: 0.5074 - val_accuracy: 0.7119
# Epoch 99/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5573 - accuracy: 0.6891 - val_loss: 0.5071 - val_accuracy: 0.7044
# Epoch 100/100
# 100/100 [==============================] - 0s 3ms/step - loss: 0.5567 - accuracy: 0.6894 - val_loss: 0.5068 - val_accuracy: 0.7220

# %%
autoencoder = load_model('model.h5')

# %%
#Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(X_test)

# %%
mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error  true_class
# count            795.000000       795.0
# mean               0.506276         0.0
# std                1.221513         0.0
# min                0.046670         0.0
# 25%                0.195453         0.0
# 50%                0.324706         0.0
# 75%                0.517929         0.0
# max               31.422172         0.0

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:1001: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning,

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %%
threshold = 2.6

# %%
# see how well we're dividing the two types of transactions:

groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
#Let's have a look at the confusion matrix:

y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]
conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))
sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title("Confusion matrix")
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()
